# %%
import pickle

# Path to the pooled features pickle file
pickle_path = 'pooled_video_features_by_video_id.pkl'  # Change path if needed

# Load the mapping from video ID to pooled feature vector
with open(pickle_path, 'rb') as f:
    video_feature_mapping = pickle.load(f)

# Example: Accessing the data
print(f"Loaded {len(video_feature_mapping)} video feature entries.\n")

# Iterate and show the shape of the first few mappings
for i, (video_id, feature_vector) in enumerate(video_feature_mapping.items()):
    print(f"Video ID: {video_id}")
    print(f"Feature vector shape: {feature_vector.shape}")
    print(f"First 10 feature values: {feature_vector[:10]}\n")
    
    if i >= 4:  # Only print first 5 entries
        break
# Out:
# Loaded 534 video feature entries.
#
# Video ID: 1tuMFJnlXJc
# Feature vector shape: (1068,)
# First 10 feature values: [-0.06040457 -0.21081842 -0.22285981 -0.39252388 -0.18916583 -0.37512335
#  -0.5231926   0.21505381  0.64515495  0.27315184]
#
# Video ID: CZigX1ntOsI
# Feature vector shape: (1068,)
# First 10 feature values: [-0.06622387 -0.30856392 -0.2354024  -0.39381802 -0.14282663 -0.35739407
#  -0.5427727   0.16601638  0.5981021   0.33628914]
#
# Video ID: G4HMKRdIva0
# Feature vector shape: (1068,)
# First 10 feature values: [-0.06494846 -0.323554   -0.19728257 -0.37274173 -0.16677982 -0.2949614
#  -0.5334089   0.13208969  0.5861574   0.24253434]
#
# Video ID: e7_2U4lm6TE
# Feature vector shape: (1068,)
# First 10 feature values: [-0.05840817 -0.2742182  -0.19230546 -0.38841173 -0.13384297 -0.36795658
#  -0.5203735   0.16043814  0.5822343   0.27939275]
#
# Video ID: MOfEl_1dh-g
# Feature vector shape: (1068,)
# First 10 feature values: [-0.07361881 -0.30221224 -0.13909729 -0.33570156 -0.18234344 -0.3431642
#  -0.4720386   0.1333883   0.59891975  0.24547486]

# %%
import torch

# Load the audio feature mapping from the .pt file
audio_dict = torch.load('audio_features_1068.pt')  # Update with your actual path

print(f"Loaded {len(audio_dict)} audio entries.\n")

for i, (video_key, content) in enumerate(audio_dict.items()):
    embedding = content['embedding']  # shape: e.g., torch.Size([512])
    label = content['label']          # shape: torch.Size([]) or int

    print(f"Audio Video Key: {video_key}")
    print(f"Embedding shape: {embedding.shape}")
    print(f"Label: {label.item() if isinstance(label, torch.Tensor) else label}")
    print(f"First 10 embedding values: {embedding[:10].tolist()}\n")

    if i >= 4:
        break
# Out:
# Loaded 755 audio entries.
#
# Audio Video Key: AmGocfFQfVE
# Embedding shape: torch.Size([1068])
# Label: Negative
# First 10 embedding values: [-0.07152270525693893, -0.04461353272199631, -0.24086812138557434, -0.4560454785823822, 0.35109537839889526, -0.3934575319290161, -0.1327846497297287, 0.3785174489021301, 0.2534216344356537, 0.761166512966156]
#
# Audio Video Key: gR4gM_WXesQ
# Embedding shape: torch.Size([1068])
# Label: Positive
# First 10 embedding values: [-0.004481568932533264, -0.2926996946334839, -0.5332130789756775, -0.16918739676475525, 0.6564330458641052, 0.0020235180854797363, -0.36786654591560364, 0.685794472694397, -0.035538747906684875, 0.8063980340957642]
#
# Audio Video Key: kZfcQ4a0kx4
# Embedding shape: torch.Size([1068])
# Label: Positive
# First 10 embedding values: [0.11859123408794403, -0.2315576821565628, -0.28997802734375, -0.4340461194515228, 0.7970811128616333, -0.38639193773269653, -0.04784702509641647, 0.38446053862571716, 0.22380605340003967, 0.80819171667099]
#
# Audio Video Key: c_FJuhSte8Q
# Embedding shape: torch.Size([1068])
# Label: Positive
# First 10 embedding values: [0.07030422985553741, -0.10572803020477295, -0.3471832275390625, -0.31543001532554626, 0.3679625689983368, -0.2273329198360443, -0.006704855710268021, 0.2631327509880066, 0.19610810279846191, 0.6106054782867432]
#
# Audio Video Key: XzVapdEr_GY
# Embedding shape: torch.Size([1068])
# Label: Positive
# First 10 embedding values: [-0.01547141745686531, -0.12890473008155823, -0.3121130168437958, -0.5439947247505188, 0.4211304485797882, -0.3445456027984619, -0.12036893516778946, 0.4018326699733734, 0.24132248759269714, 0.683375358581543]
# /tmp/ipykernel_3897072/1643089461.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   audio_dict = torch.load('audio_features_1068.pt')  # Update with your actual path

# %%
import pickle
import torch
import numpy as np

# Load video features (np.array)
with open('pooled_video_features_by_video_id.pkl', 'rb') as f:
    video_dict = pickle.load(f)  # dict[video_id] = np.array(1068,)

# Load audio features (torch.Tensor)
audio_dict = torch.load('audio_features_1068.pt')  # dict[video_id]['embedding'] = Tensor

# Load text features (.npy as dict)
text_dict = np.load('video_segment_word_embeddings.npy', allow_pickle=True).item()  # dict[video_id] = np.array(768,)

# Find common video IDs
common_ids = set(video_dict.keys()) & set(audio_dict.keys()) & set(text_dict.keys())
print(f"Found {len(common_ids)} common video IDs across video, audio, and text modalities.\n")

# Example: Check one aligned set
for vid in sorted(common_ids):
    video_feat = video_dict[vid]                                      # shape: (1068,)
    audio_feat = audio_dict[vid]['embedding'].detach().numpy()       # shape: (512,)
    text_feat = np.array(text_dict[vid])                              # convert list to array

    print(f"Video ID: {vid}")
    print(f"  Video feat shape: {video_feat.shape}")
    print(f"  Audio feat shape: {audio_feat.shape}")
    print(f"  Text  feat shape: {text_feat.shape}")
    break
# Out:
# Found 534 common video IDs across video, audio, and text modalities.
#
# Video ID: -3g5yACwYnA
#   Video feat shape: (1068,)
#   Audio feat shape: (1068,)
#   Text  feat shape: (1, 1068)
# /tmp/ipykernel_3906577/3713251298.py:10: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   audio_dict = torch.load('audio_features_1068.pt')  # dict[video_id]['embedding'] = Tensor

# %%
import pandas as pd

# Load the CSV file
csv_path = "/data/home/huixian/Documents/Homeworks/535_project/MOSEI-Seg/Labels/new_sentiment_split_2.csv"  # Replace with your actual CSV file path
df = pd.read_csv(csv_path)

# Count unique video IDs
unique_video_ids = df['video_id'].nunique()
print(f"Number of unique video IDs: {unique_video_ids}")
# Out:
# Number of unique video IDs: 755

# %%
import torch
import pickle
import numpy as np
import pandas as pd

# Load input files
with open("pooled_video_features_by_video_id.pkl", "rb") as f:
    video_dict = pickle.load(f)

audio_dict = torch.load("audio_features_1068.pt")
text_dict = np.load("/data/home/huixian/Documents/Homeworks/535_project/mosei_code/video_segment_word_embeddings.npy", allow_pickle=True).item()

# Load split mapping from CSV
csv_path = "/data/home/huixian/Documents/Homeworks/535_project/MOSEI-Seg/Labels/new_sentiment_split_2.csv"
df = pd.read_csv(csv_path)
split_map = df.drop_duplicates(subset='video_id')[['video_id', 'split']].set_index('video_id')['split'].to_dict()

# Build fused features [(video_id, torch.tensor([video, audio, text]), label, split)]
fused_data = []
for vid in set(video_dict) & set(audio_dict) & set(text_dict) & set(split_map):
    try:
        video_feat = np.array(video_dict[vid])
        audio_feat = audio_dict[vid]['embedding'].detach().numpy()
        text_feat = np.array(text_dict[vid]).squeeze()

        fused_tensor = torch.tensor(np.stack([video_feat, audio_feat, text_feat], axis=0), dtype=torch.float32)

        label = audio_dict[vid]['label']
        if isinstance(label, torch.Tensor):
            label = label.item()

        split = split_map[vid]
        fused_data.append((vid, fused_tensor, label, split))
    except Exception as e:
        print(f"⚠️ Skipping {vid} due to error: {e}")

# Summary
print(f"✅ Total samples fused: {len(fused_data)}")
for s in ['train', 'val', 'test']:
    count = sum(1 for item in fused_data if item[3] == s)
    print(f"{s}: {count}")

# Save to pickle for reuse
with open("fused_tensor_data.pkl", "wb") as f:
    pickle.dump(fused_data, f)
# Out:
# ✅ Total samples fused: 755
# train: 534
# val: 107
# test: 114
# /tmp/ipykernel_3975008/4136055895.py:10: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   audio_dict = torch.load("audio_features_1068.pt")

# %%
import os
gpu_ids = [4]
os.environ["CUDA_VISIBLE_DEVICES"] = ",".join(map(str, gpu_ids))
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import pickle
from sklearn.metrics import f1_score, accuracy_score, recall_score
import numpy as np
import random

# -------------------------------
# Set Seed for Reproducibility
# -------------------------------

def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# -------------------------------
# Label mapping
# -------------------------------

label_map = {"Negative": 0, "Neutral": 1, "Positive": 2}

# -------------------------------
# Dataset
# -------------------------------

class FusedDataset(Dataset):
    def __init__(self, data):
        self.data = data

    def __getitem__(self, idx):
        _, feature, label, _ = self.data[idx]

        if isinstance(label, str):
            label = label_map[label]
        elif isinstance(label, float):
            label = 0 if label < 0 else 2 if label > 0 else 1

        return feature, label

    def __len__(self):
        return len(self.data)

def prepare_dataloaders(pickle_path, batch_size=32):
    with open(pickle_path, 'rb') as f:
        data = pickle.load(f)

    splits = {'train': [], 'val': [], 'test': []}
    for item in data:
        splits[item[3]].append(item)

    train_loader = DataLoader(FusedDataset(splits['train']), batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(FusedDataset(splits['val']), batch_size=batch_size)
    test_loader = DataLoader(FusedDataset(splits['test']), batch_size=batch_size)
    return train_loader, val_loader, test_loader

# -------------------------------
# Model
# -------------------------------

class EarlyFusionTransformer(nn.Module):
    def __init__(self, input_dim=1068, num_classes=3, num_heads=4, hidden_dim=512):
        super().__init__()
        self.pos_embed = nn.Parameter(torch.zeros(1, 3, input_dim))
        self.encoder = nn.TransformerEncoder(
            nn.TransformerEncoderLayer(d_model=input_dim, nhead=num_heads, dim_feedforward=hidden_dim, dropout=0.1, batch_first=True),
            num_layers=2
        )
        self.classifier = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(hidden_dim, num_classes)
        )

    def forward(self, x):
        x = x + self.pos_embed
        x = self.encoder(x)
        x = x.mean(dim=1)
        return self.classifier(x)

# -------------------------------
# Evaluation
# -------------------------------

def evaluate(model, loader, device, criterion):
    model.eval()
    all_preds, all_labels = [], []
    total_loss = 0.0
    with torch.no_grad():
        for feats, labels in loader:
            feats = feats.to(device).view(feats.size(0), 3, 1068)
            labels = labels.clone().detach().to(device)

            logits = model(feats)
            loss = criterion(logits, labels)
            total_loss += loss.item()

            preds = torch.argmax(logits, dim=1)
            all_preds.append(preds.cpu())
            all_labels.append(labels.cpu())

    y_true = torch.cat(all_labels).numpy()
    y_pred = torch.cat(all_preds).numpy()

    metrics = {
        'loss': total_loss / len(loader),
        'micro_f1': f1_score(y_true, y_pred, average='micro'),
        'macro_f1': f1_score(y_true, y_pred, average='macro'),
        'accuracy': accuracy_score(y_true, y_pred),
        'recall': recall_score(y_true, y_pred, average=None)
    }
    return metrics

# -------------------------------
# Training Loop
# -------------------------------

def train_model():
    set_seed(42)
    train_loader, val_loader, test_loader = prepare_dataloaders('fused_tensor_data.pkl')
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    model = EarlyFusionTransformer().to(device)
    optimizer = torch.optim.AdamW(model.parameters(), lr=1e-4)
    criterion = nn.CrossEntropyLoss()

    best_val_macro_f1 = 0.0
    best_model_state = None

    for epoch in range(1, 101):
        model.train()
        total_loss = 0.0
        all_preds, all_labels = [], []

        for feats, labels in train_loader:
            feats = feats.to(device).view(feats.size(0), 3, 1068)
            labels = labels.clone().detach().to(device)

            optimizer.zero_grad()
            logits = model(feats)
            loss = criterion(logits, labels)
            loss.backward()
            optimizer.step()

            total_loss += loss.item()
            preds = torch.argmax(logits, dim=1)
            all_preds.append(preds.cpu())
            all_labels.append(labels.cpu())

        y_train_true = torch.cat(all_labels).numpy()
        y_train_pred = torch.cat(all_preds).numpy()

        train_loss = total_loss / len(train_loader)
        train_metrics = {
            'macro_f1': f1_score(y_train_true, y_train_pred, average='macro'),
            'micro_f1': f1_score(y_train_true, y_train_pred, average='micro'),
            'accuracy': accuracy_score(y_train_true, y_train_pred),
            'recall': recall_score(y_train_true, y_train_pred, average=None)
        }

        val_metrics = evaluate(model, val_loader, device, criterion)

        print(f"\nEpoch {epoch}")
        print(f"Train Loss: {train_loss:.4f} | Val Loss: {val_metrics['loss']:.4f}")
        print(f"Macro-F1: {val_metrics['macro_f1']:.4f} | Micro-F1: {val_metrics['micro_f1']:.4f} | Acc: {val_metrics['accuracy']:.4f} | Recall: {val_metrics['recall']}")

        if val_metrics['macro_f1'] > best_val_macro_f1:
            best_val_macro_f1 = val_metrics['macro_f1']
            best_model_state = model.state_dict()
            print("✅New best model saved.")

    # Final evaluation
    model.load_state_dict(best_model_state)
    test_metrics = evaluate(model, test_loader, device, criterion)

    print("\nFINAL TEST EVALUATION")
    print(f"Test Loss : {test_metrics['loss']:.4f}")
    print(f"Macro-F1  : {test_metrics['macro_f1']:.4f}")
    print(f"Micro-F1  : {test_metrics['micro_f1']:.4f}")
    print(f"Accuracy  : {test_metrics['accuracy']:.4f}")
    print(f"Recall    : {test_metrics['recall']}")

    torch.save(model.state_dict(), "best_early_fusion_model.pth")

if __name__ == "__main__":
    train_model()
# Out:
# Epoch 1
# Train Loss: 0.9663 | Val Loss: 0.9873
# Macro-F1: 0.2786 | Micro-F1: 0.6168 | Acc: 0.6168 | Recall: [0.         0.04761905 0.91549296]
# ✅New best model saved.
#
# Epoch 2
# Train Loss: 0.9276 | Val Loss: 0.9256
# Macro-F1: 0.2659 | Micro-F1: 0.6636 | Acc: 0.6636 | Recall: [0. 0. 1.]
#
# Epoch 3
# Train Loss: 0.9283 | Val Loss: 0.9317
# Macro-F1: 0.2659 | Micro-F1: 0.6636 | Acc: 0.6636 | Recall: [0. 0. 1.]
#
# Epoch 4
# Train Loss: 0.8941 | Val Loss: 0.9305
# Macro-F1: 0.2614 | Micro-F1: 0.6449 | Acc: 0.6449 | Recall: [0.         0.         0.97183099]
#
# Epoch 5
# Train Loss: 0.8939 | Val Loss: 0.9582
# Macro-F1: 0.2971 | Micro-F1: 0.5794 | Acc: 0.5794 | Recall: [0.         0.14285714 0.83098592]
# ✅New best model saved.
#
# Epoch 6
# Train Loss: 0.9051 | Val Loss: 0.9612
# Macro-F1: 0.3074 | Micro-F1: 0.5140 | Acc: 0.5140 | Recall: [0.         0.33333333 0.67605634]
# ✅New best model saved.
#
# Epoch 7
# Train Loss: 0.8737 | Val Loss: 0.9493
# Macro-F1: 0.3123 | Micro-F1: 0.5607 | Acc: 0.5607 | Recall: [0.         0.23809524 0.77464789]
# ✅New best model saved.
#
# Epoch 8
# Train Loss: 0.8509 | Val Loss: 1.0022
# Macro-F1: 0.3187 | Micro-F1: 0.4579 | Acc: 0.4579 | Recall: [0.         0.76190476 0.46478873]
# ✅New best model saved.
#
# Epoch 9
# Train Loss: 0.8148 | Val Loss: 0.9647
# Macro-F1: 0.3063 | Micro-F1: 0.5701 | Acc: 0.5701 | Recall: [0.         0.19047619 0.8028169 ]
#
# Epoch 10
# Train Loss: 0.7634 | Val Loss: 0.8679
# Macro-F1: 0.4574 | Micro-F1: 0.6168 | Acc: 0.6168 | Recall: [0.13333333 0.52380952 0.74647887]
# ✅New best model saved.
#
# Epoch 11
# Train Loss: 0.8066 | Val Loss: 0.9831
# Macro-F1: 0.3133 | Micro-F1: 0.6168 | Acc: 0.6168 | Recall: [0.         0.14285714 0.88732394]
#
# Epoch 12
# Train Loss: 0.7853 | Val Loss: 0.8489
# Macro-F1: 0.4697 | Micro-F1: 0.6355 | Acc: 0.6355 | Recall: [0.2        0.38095238 0.8028169 ]
# ✅New best model saved.
#
# Epoch 13
# Train Loss: 0.7484 | Val Loss: 0.9308
# Macro-F1: 0.3804 | Micro-F1: 0.5701 | Acc: 0.5701 | Recall: [0.         0.71428571 0.64788732]
#
# Epoch 14
# Train Loss: 0.7033 | Val Loss: 0.9399
# Macro-F1: 0.3615 | Micro-F1: 0.6075 | Acc: 0.6075 | Recall: [0.06666667 0.19047619 0.84507042]
#
# Epoch 15
# Train Loss: 0.7200 | Val Loss: 0.8269
# Macro-F1: 0.4998 | Micro-F1: 0.6729 | Acc: 0.6729 | Recall: [0.2        0.42857143 0.84507042]
# ✅New best model saved.
#
# Epoch 16
# Train Loss: 0.6787 | Val Loss: 0.9481
# Macro-F1: 0.4582 | Micro-F1: 0.5234 | Acc: 0.5234 | Recall: [0.2        0.85714286 0.49295775]
#
# Epoch 17
# Train Loss: 0.6367 | Val Loss: 1.0084
# Macro-F1: 0.3610 | Micro-F1: 0.6355 | Acc: 0.6355 | Recall: [0.06666667 0.14285714 0.90140845]
#
# Epoch 18
# Train Loss: 0.7194 | Val Loss: 0.9571
# Macro-F1: 0.3029 | Micro-F1: 0.5888 | Acc: 0.5888 | Recall: [0.         0.14285714 0.84507042]
#
# Epoch 19
# Train Loss: 0.6851 | Val Loss: 0.8363
# Macro-F1: 0.5349 | Micro-F1: 0.7103 | Acc: 0.7103 | Recall: [0.4        0.19047619 0.92957746]
# ✅New best model saved.
#
# Epoch 20
# Train Loss: 0.6072 | Val Loss: 0.9456
# Macro-F1: 0.5179 | Micro-F1: 0.6355 | Acc: 0.6355 | Recall: [0.2        0.76190476 0.69014085]
#
# Epoch 21
# Train Loss: 0.6402 | Val Loss: 0.8877
# Macro-F1: 0.4853 | Micro-F1: 0.5981 | Acc: 0.5981 | Recall: [0.2        0.61904762 0.67605634]
#
# Epoch 22
# Train Loss: 0.6820 | Val Loss: 0.9265
# Macro-F1: 0.4749 | Micro-F1: 0.6355 | Acc: 0.6355 | Recall: [0.2        0.38095238 0.8028169 ]
#
# Epoch 23
# Train Loss: 0.6742 | Val Loss: 0.8653
# Macro-F1: 0.4997 | Micro-F1: 0.6075 | Acc: 0.6075 | Recall: [0.2        0.71428571 0.66197183]
#
# Epoch 24
# Train Loss: 0.5850 | Val Loss: 0.8772
# Macro-F1: 0.5335 | Micro-F1: 0.6168 | Acc: 0.6168 | Recall: [0.53333333 0.38095238 0.70422535]
#
# Epoch 25
# Train Loss: 0.5713 | Val Loss: 0.8902
# Macro-F1: 0.4853 | Micro-F1: 0.6636 | Acc: 0.6636 | Recall: [0.26666667 0.28571429 0.85915493]
#
# Epoch 26
# Train Loss: 0.5686 | Val Loss: 0.9549
# Macro-F1: 0.5296 | Micro-F1: 0.6449 | Acc: 0.6449 | Recall: [0.2        0.80952381 0.69014085]
#
# Epoch 27
# Train Loss: 0.5986 | Val Loss: 0.9445
# Macro-F1: 0.5269 | Micro-F1: 0.5607 | Acc: 0.5607 | Recall: [0.66666667 0.57142857 0.53521127]
#
# Epoch 28
# Train Loss: 0.5856 | Val Loss: 0.8625
# Macro-F1: 0.4681 | Micro-F1: 0.6355 | Acc: 0.6355 | Recall: [0.13333333 0.52380952 0.77464789]
#
# Epoch 29
# Train Loss: 0.5827 | Val Loss: 1.0241
# Macro-F1: 0.4971 | Micro-F1: 0.6916 | Acc: 0.6916 | Recall: [0.13333333 0.47619048 0.87323944]
#
# Epoch 30
# Train Loss: 0.6183 | Val Loss: 0.9519
# Macro-F1: 0.4839 | Micro-F1: 0.6355 | Acc: 0.6355 | Recall: [0.13333333 0.66666667 0.73239437]
#
# Epoch 31
# Train Loss: 0.5509 | Val Loss: 0.9067
# Macro-F1: 0.4933 | Micro-F1: 0.6542 | Acc: 0.6542 | Recall: [0.2        0.42857143 0.81690141]
#
# Epoch 32
# Train Loss: 0.5417 | Val Loss: 1.0232
# Macro-F1: 0.4936 | Micro-F1: 0.5701 | Acc: 0.5701 | Recall: [0.26666667 0.66666667 0.6056338 ]
#
# Epoch 33
# Train Loss: 0.5438 | Val Loss: 1.0927
# Macro-F1: 0.4583 | Micro-F1: 0.6636 | Acc: 0.6636 | Recall: [0.06666667 0.57142857 0.81690141]
#
# Epoch 34
# Train Loss: 0.5700 | Val Loss: 0.8993
# Macro-F1: 0.5081 | Micro-F1: 0.6916 | Acc: 0.6916 | Recall: [0.2        0.38095238 0.88732394]
#
# Epoch 35
# Train Loss: 0.5277 | Val Loss: 0.9414
# Macro-F1: 0.5609 | Micro-F1: 0.6168 | Acc: 0.6168 | Recall: [0.53333333 0.61904762 0.63380282]
# ✅New best model saved.
#
# Epoch 36
# Train Loss: 0.5671 | Val Loss: 1.0421
# Macro-F1: 0.4795 | Micro-F1: 0.5140 | Acc: 0.5140 | Recall: [0.33333333 0.71428571 0.49295775]
#
# Epoch 37
# Train Loss: 0.5541 | Val Loss: 0.8963
# Macro-F1: 0.4806 | Micro-F1: 0.6262 | Acc: 0.6262 | Recall: [0.2        0.47619048 0.76056338]
#
# Epoch 38
# Train Loss: 0.5409 | Val Loss: 0.9903
# Macro-F1: 0.4367 | Micro-F1: 0.6262 | Acc: 0.6262 | Recall: [0.06666667 0.57142857 0.76056338]
#
# Epoch 39
# Train Loss: 0.4779 | Val Loss: 0.9839
# Macro-F1: 0.5281 | Micro-F1: 0.6916 | Acc: 0.6916 | Recall: [0.2        0.52380952 0.84507042]
#
# Epoch 40
# Train Loss: 0.4898 | Val Loss: 1.0384
# Macro-F1: 0.5177 | Micro-F1: 0.5794 | Acc: 0.5794 | Recall: [0.46666667 0.52380952 0.61971831]
#
# Epoch 41
# Train Loss: 0.4699 | Val Loss: 0.9218
# Macro-F1: 0.5944 | Micro-F1: 0.6916 | Acc: 0.6916 | Recall: [0.53333333 0.42857143 0.8028169 ]
# ✅New best model saved.
#
# Epoch 42
# Train Loss: 0.4586 | Val Loss: 0.9572
# Macro-F1: 0.6240 | Micro-F1: 0.7009 | Acc: 0.7009 | Recall: [0.53333333 0.47619048 0.8028169 ]
# ✅New best model saved.
#
# Epoch 43
# Train Loss: 0.4368 | Val Loss: 1.1218
# Macro-F1: 0.5525 | Micro-F1: 0.5888 | Acc: 0.5888 | Recall: [0.6        0.66666667 0.56338028]
#
# Epoch 44
# Train Loss: 0.5485 | Val Loss: 0.9897
# Macro-F1: 0.5280 | Micro-F1: 0.6168 | Acc: 0.6168 | Recall: [0.4        0.42857143 0.71830986]
#
# Epoch 45
# Train Loss: 0.4758 | Val Loss: 1.1102
# Macro-F1: 0.4654 | Micro-F1: 0.6075 | Acc: 0.6075 | Recall: [0.13333333 0.66666667 0.69014085]
#
# Epoch 46
# Train Loss: 0.4443 | Val Loss: 1.0308
# Macro-F1: 0.5596 | Micro-F1: 0.6449 | Acc: 0.6449 | Recall: [0.33333333 0.66666667 0.70422535]
#
# Epoch 47
# Train Loss: 0.4486 | Val Loss: 1.0154
# Macro-F1: 0.5220 | Micro-F1: 0.6729 | Acc: 0.6729 | Recall: [0.53333333 0.19047619 0.84507042]
#
# Epoch 48
# Train Loss: 0.3913 | Val Loss: 1.1000
# Macro-F1: 0.5142 | Micro-F1: 0.6729 | Acc: 0.6729 | Recall: [0.2        0.52380952 0.81690141]
#
# Epoch 49
# Train Loss: 0.3560 | Val Loss: 1.1414
# Macro-F1: 0.5147 | Micro-F1: 0.6636 | Acc: 0.6636 | Recall: [0.26666667 0.42857143 0.81690141]
#
# Epoch 50
# Train Loss: 0.3776 | Val Loss: 1.2000
# Macro-F1: 0.5558 | Micro-F1: 0.5981 | Acc: 0.5981 | Recall: [0.66666667 0.57142857 0.5915493 ]
#
# Epoch 51
# Train Loss: 0.3775 | Val Loss: 1.2242
# Macro-F1: 0.5099 | Micro-F1: 0.5981 | Acc: 0.5981 | Recall: [0.26666667 0.66666667 0.64788732]
#
# Epoch 52
# Train Loss: 0.4024 | Val Loss: 1.0020
# Macro-F1: 0.5762 | Micro-F1: 0.6729 | Acc: 0.6729 | Recall: [0.33333333 0.71428571 0.73239437]
#
# Epoch 53
# Train Loss: 0.3934 | Val Loss: 1.3159
# Macro-F1: 0.3456 | Micro-F1: 0.6355 | Acc: 0.6355 | Recall: [0.06666667 0.0952381  0.91549296]
#
# Epoch 54
# Train Loss: 0.4146 | Val Loss: 1.0596
# Macro-F1: 0.5350 | Micro-F1: 0.6636 | Acc: 0.6636 | Recall: [0.33333333 0.42857143 0.8028169 ]
#
# Epoch 55
# Train Loss: 0.3496 | Val Loss: 1.1299
# Macro-F1: 0.5525 | Micro-F1: 0.6636 | Acc: 0.6636 | Recall: [0.26666667 0.61904762 0.76056338]
#
# Epoch 56
# Train Loss: 0.3686 | Val Loss: 1.1440
# Macro-F1: 0.5426 | Micro-F1: 0.6636 | Acc: 0.6636 | Recall: [0.26666667 0.57142857 0.77464789]
#
# Epoch 57
# Train Loss: 0.3612 | Val Loss: 1.4525
# Macro-F1: 0.4303 | Micro-F1: 0.5981 | Acc: 0.5981 | Recall: [0.06666667 0.66666667 0.69014085]
#
# Epoch 58
# Train Loss: 0.3776 | Val Loss: 1.1335
# Macro-F1: 0.4621 | Micro-F1: 0.6355 | Acc: 0.6355 | Recall: [0.2        0.33333333 0.81690141]
#
# Epoch 59
# Train Loss: 0.3108 | Val Loss: 1.4232
# Macro-F1: 0.4898 | Micro-F1: 0.5421 | Acc: 0.5421 | Recall: [0.4        0.57142857 0.56338028]
#
# Epoch 60
# Train Loss: 0.4411 | Val Loss: 1.2030
# Macro-F1: 0.5630 | Micro-F1: 0.6355 | Acc: 0.6355 | Recall: [0.4        0.66666667 0.67605634]
#
# Epoch 61
# Train Loss: 0.5468 | Val Loss: 1.0307
# Macro-F1: 0.4541 | Micro-F1: 0.5140 | Acc: 0.5140 | Recall: [0.46666667 0.42857143 0.54929577]
#
# Epoch 62
# Train Loss: 0.4693 | Val Loss: 1.0563
# Macro-F1: 0.5729 | Micro-F1: 0.6729 | Acc: 0.6729 | Recall: [0.4        0.47619048 0.78873239]
#
# Epoch 63
# Train Loss: 0.3558 | Val Loss: 1.2369
# Macro-F1: 0.4846 | Micro-F1: 0.5794 | Acc: 0.5794 | Recall: [0.26666667 0.52380952 0.66197183]
#
# Epoch 64
# Train Loss: 0.3441 | Val Loss: 1.1627
# Macro-F1: 0.5112 | Micro-F1: 0.6355 | Acc: 0.6355 | Recall: [0.26666667 0.47619048 0.76056338]
#
# Epoch 65
# Train Loss: 0.2956 | Val Loss: 1.1656
# Macro-F1: 0.5910 | Micro-F1: 0.6542 | Acc: 0.6542 | Recall: [0.46666667 0.57142857 0.71830986]
#
# Epoch 66
# Train Loss: 0.2831 | Val Loss: 1.2460
# Macro-F1: 0.5908 | Micro-F1: 0.6729 | Acc: 0.6729 | Recall: [0.4        0.57142857 0.76056338]
#
# Epoch 67
# Train Loss: 0.3075 | Val Loss: 1.2293
# Macro-F1: 0.5136 | Micro-F1: 0.6355 | Acc: 0.6355 | Recall: [0.6        0.23809524 0.76056338]
#
# Epoch 68
# Train Loss: 0.3708 | Val Loss: 1.1630
# Macro-F1: 0.4775 | Micro-F1: 0.6262 | Acc: 0.6262 | Recall: [0.26666667 0.33333333 0.78873239]
#
# Epoch 69
# Train Loss: 0.2747 | Val Loss: 1.3911
# Macro-F1: 0.4824 | Micro-F1: 0.5888 | Acc: 0.5888 | Recall: [0.26666667 0.52380952 0.67605634]
#
# Epoch 70
# Train Loss: 0.3095 | Val Loss: 1.1875
# Macro-F1: 0.4460 | Micro-F1: 0.6355 | Acc: 0.6355 | Recall: [0.13333333 0.38095238 0.81690141]
#
# Epoch 71
# Train Loss: 0.2612 | Val Loss: 1.3402
# Macro-F1: 0.5037 | Micro-F1: 0.6075 | Acc: 0.6075 | Recall: [0.4        0.42857143 0.70422535]
#
# Epoch 72
# Train Loss: 0.2209 | Val Loss: 1.3968
# Macro-F1: 0.4921 | Micro-F1: 0.6636 | Acc: 0.6636 | Recall: [0.26666667 0.28571429 0.85915493]
#
# Epoch 73
# Train Loss: 0.3712 | Val Loss: 1.0230
# Macro-F1: 0.5672 | Micro-F1: 0.6916 | Acc: 0.6916 | Recall: [0.26666667 0.66666667 0.78873239]
#
# Epoch 74
# Train Loss: 0.4618 | Val Loss: 1.0311
# Macro-F1: 0.5693 | Micro-F1: 0.6542 | Acc: 0.6542 | Recall: [0.46666667 0.52380952 0.73239437]
#
# Epoch 75
# Train Loss: 0.2671 | Val Loss: 1.4269
# Macro-F1: 0.4933 | Micro-F1: 0.5981 | Acc: 0.5981 | Recall: [0.2        0.66666667 0.66197183]
#
# Epoch 76
# Train Loss: 0.3268 | Val Loss: 1.6196
# Macro-F1: 0.4107 | Micro-F1: 0.6449 | Acc: 0.6449 | Recall: [0.06666667 0.33333333 0.85915493]
#
# Epoch 77
# Train Loss: 0.3743 | Val Loss: 0.9538
# Macro-F1: 0.4889 | Micro-F1: 0.6542 | Acc: 0.6542 | Recall: [0.33333333 0.23809524 0.84507042]
#
# Epoch 78
# Train Loss: 0.2541 | Val Loss: 1.4072
# Macro-F1: 0.4918 | Micro-F1: 0.6636 | Acc: 0.6636 | Recall: [0.13333333 0.57142857 0.8028169 ]
#
# Epoch 79
# Train Loss: 0.2394 | Val Loss: 1.3572
# Macro-F1: 0.5195 | Micro-F1: 0.6636 | Acc: 0.6636 | Recall: [0.26666667 0.42857143 0.81690141]
#
# Epoch 80
# Train Loss: 0.2459 | Val Loss: 1.4007
# Macro-F1: 0.4705 | Micro-F1: 0.6729 | Acc: 0.6729 | Recall: [0.2        0.28571429 0.88732394]
#
# Epoch 81
# Train Loss: 0.2094 | Val Loss: 1.2748
# Macro-F1: 0.5024 | Micro-F1: 0.6822 | Acc: 0.6822 | Recall: [0.2        0.38095238 0.87323944]
#
# Epoch 82
# Train Loss: 0.2163 | Val Loss: 1.5455
# Macro-F1: 0.5291 | Micro-F1: 0.6636 | Acc: 0.6636 | Recall: [0.26666667 0.47619048 0.8028169 ]
#
# Epoch 83
# Train Loss: 0.2349 | Val Loss: 1.3787
# Macro-F1: 0.4621 | Micro-F1: 0.5794 | Acc: 0.5794 | Recall: [0.4        0.28571429 0.70422535]
#
# Epoch 84
# Train Loss: 0.1896 | Val Loss: 1.5248
# Macro-F1: 0.5435 | Micro-F1: 0.6262 | Acc: 0.6262 | Recall: [0.33333333 0.66666667 0.67605634]
#
# Epoch 85
# Train Loss: 0.1940 | Val Loss: 1.6112
# Macro-F1: 0.4611 | Micro-F1: 0.6075 | Acc: 0.6075 | Recall: [0.2        0.47619048 0.73239437]
#
# Epoch 86
# Train Loss: 0.1571 | Val Loss: 1.7075
# Macro-F1: 0.4463 | Micro-F1: 0.6168 | Acc: 0.6168 | Recall: [0.13333333 0.42857143 0.77464789]
#
# Epoch 87
# Train Loss: 0.1519 | Val Loss: 1.5768
# Macro-F1: 0.5176 | Micro-F1: 0.6542 | Acc: 0.6542 | Recall: [0.33333333 0.38095238 0.8028169 ]
#
# Epoch 88
# Train Loss: 0.1581 | Val Loss: 1.9710
# Macro-F1: 0.4918 | Micro-F1: 0.5981 | Acc: 0.5981 | Recall: [0.2        0.76190476 0.63380282]
#
# Epoch 89
# Train Loss: 0.2337 | Val Loss: 1.5062
# Macro-F1: 0.4466 | Micro-F1: 0.6729 | Acc: 0.6729 | Recall: [0.26666667 0.0952381  0.92957746]
#
# Epoch 90
# Train Loss: 0.4536 | Val Loss: 1.3565
# Macro-F1: 0.4897 | Micro-F1: 0.6542 | Acc: 0.6542 | Recall: [0.13333333 0.61904762 0.77464789]
#
# Epoch 91
# Train Loss: 0.5039 | Val Loss: 1.3332
# Macro-F1: 0.4333 | Micro-F1: 0.6542 | Acc: 0.6542 | Recall: [0.06666667 0.42857143 0.84507042]
#
# Epoch 92
# Train Loss: 0.3204 | Val Loss: 1.3988
# Macro-F1: 0.3874 | Micro-F1: 0.6075 | Acc: 0.6075 | Recall: [0.2        0.0952381  0.84507042]
#
# Epoch 93
# Train Loss: 0.3061 | Val Loss: 1.7400
# Macro-F1: 0.4113 | Micro-F1: 0.4766 | Acc: 0.4766 | Recall: [0.73333333 0.19047619 0.50704225]
#
# Epoch 94
# Train Loss: 0.2906 | Val Loss: 1.4925
# Macro-F1: 0.5740 | Micro-F1: 0.6916 | Acc: 0.6916 | Recall: [0.33333333 0.47619048 0.83098592]
#
# Epoch 95
# Train Loss: 0.1978 | Val Loss: 1.5001
# Macro-F1: 0.5672 | Micro-F1: 0.6542 | Acc: 0.6542 | Recall: [0.4        0.47619048 0.76056338]
#
# Epoch 96
# Train Loss: 0.2493 | Val Loss: 1.6597
# Macro-F1: 0.4696 | Micro-F1: 0.6262 | Acc: 0.6262 | Recall: [0.26666667 0.33333333 0.78873239]
#
# Epoch 97
# Train Loss: 0.3676 | Val Loss: 1.5682
# Macro-F1: 0.3649 | Micro-F1: 0.6449 | Acc: 0.6449 | Recall: [0.06666667 0.14285714 0.91549296]
#
# Epoch 98
# Train Loss: 0.3264 | Val Loss: 1.5807
# Macro-F1: 0.4718 | Micro-F1: 0.5607 | Acc: 0.5607 | Recall: [0.2        0.71428571 0.5915493 ]
#
# Epoch 99
# Train Loss: 0.3298 | Val Loss: 1.8025
# Macro-F1: 0.4397 | Micro-F1: 0.5140 | Acc: 0.5140 | Recall: [0.33333333 0.52380952 0.54929577]
#
# Epoch 100
# Train Loss: 0.3245 | Val Loss: 1.5444
# Macro-F1: 0.4998 | Micro-F1: 0.6075 | Acc: 0.6075 | Recall: [0.26666667 0.52380952 0.70422535]
#
# FINAL TEST EVALUATION
# Test Loss : 1.3030
# Macro-F1  : 0.5642
# Micro-F1  : 0.6404
# Accuracy  : 0.6404
# Recall    : [0.5        0.34482759 0.79710145]

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import pickle
from sklearn.metrics import f1_score, accuracy_score, recall_score
import numpy as np
import random

# -------------------------------
# Set Seed
# -------------------------------

def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# -------------------------------
# Dataset
# -------------------------------

class ConcatFusedDataset(Dataset):
    def __init__(self, data):
        self.data = data
        self.label_map = {"Negative": 0, "Neutral": 1, "Positive": 2}

    def __getitem__(self, idx):
        video_id, fused_tensor, label, split = self.data[idx]

        if isinstance(label, str):
            label = self.label_map[label]
        elif isinstance(label, float):
            label = 0 if label < 0 else 2 if label > 0 else 1

        # Flatten tensor: shape [3, D] -> [3*D]
        return fused_tensor.flatten(), torch.tensor(label, dtype=torch.long)

    def __len__(self):
        return len(self.data)



# -------------------------------
# Dataloader Preparation
# -------------------------------

def prepare_dataloaders(pickle_path, batch_size=32):
    # Load fused data
    with open(pickle_path, 'rb') as f:
        data = pickle.load(f)

    # Organize by split
    splits = {'train': [], 'val': [], 'test': []}
    for item in data:
        video_id, fused_tensor, label, split = item
        if split in splits:
            splits[split].append(item)

    print("📊 Split sizes:", {k: len(v) for k, v in splits.items()})

    if len(splits['train']) == 0:
        raise ValueError("🚨 Training split is empty. Verify the pickle includes split info.")

    train_loader = DataLoader(ConcatFusedDataset(splits['train']), batch_size=batch_size, shuffle=True)
    val_loader   = DataLoader(ConcatFusedDataset(splits['val']), batch_size=batch_size)
    test_loader  = DataLoader(ConcatFusedDataset(splits['test']), batch_size=batch_size)
    return train_loader, val_loader, test_loader

# -------------------------------
# Simple Concatenation MLP Model
# -------------------------------

class SimpleConcatMLP(nn.Module):
    def __init__(self, input_dim=3204, hidden_dim=512, num_classes=3):
        super().__init__()
        self.model = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(hidden_dim, num_classes)
        )

    def forward(self, x):
        return self.model(x)



# -------------------------------
# Evaluation Function
# -------------------------------

def evaluate(model, loader, device, criterion):
    model.eval()
    all_preds, all_labels = [], []
    total_loss = 0.0

    with torch.no_grad():
        for feats, labels in loader:
            feats = feats.to(device)
            labels = labels.to(device)

            logits = model(feats)
            loss = criterion(logits, labels)
            total_loss += loss.item()

            preds = torch.argmax(logits, dim=1)
            all_preds.append(preds.cpu())
            all_labels.append(labels.cpu())

    y_true = torch.cat(all_labels).numpy()
    y_pred = torch.cat(all_preds).numpy()

    metrics = {
        'loss': total_loss / len(loader),
        'micro_f1': f1_score(y_true, y_pred, average='micro'),
        'macro_f1': f1_score(y_true, y_pred, average='macro'),
        'accuracy': accuracy_score(y_true, y_pred),
        'recall': recall_score(y_true, y_pred, average=None)
    }
    return metrics

# -------------------------------
# Training Loop
# -------------------------------

def train_model():
    set_seed(42)
    pickle_path = "fused_tensor_data.pkl"
    train_loader, val_loader, test_loader = prepare_dataloaders(pickle_path, batch_size=32)

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = SimpleConcatMLP(input_dim=3204).to(device)
    optimizer = torch.optim.AdamW(model.parameters(), lr=1e-4)
    criterion = nn.CrossEntropyLoss()

    best_val_macro_f1 = 0.0
    best_model_state = None

    for epoch in range(1, 301):
        model.train()
        total_loss = 0.0
        all_preds, all_labels = [], []

        for feats, labels in train_loader:
            feats = feats.to(device)
            labels = labels.to(device)

            optimizer.zero_grad()
            logits = model(feats)
            loss = criterion(logits, labels)
            loss.backward()
            optimizer.step()

            total_loss += loss.item()
            preds = torch.argmax(logits, dim=1)
            all_preds.append(preds.cpu())
            all_labels.append(labels.cpu())

        y_train_true = torch.cat(all_labels).numpy()
        y_train_pred = torch.cat(all_preds).numpy()

        train_loss = total_loss / len(train_loader)
        train_metrics = {
            'macro_f1': f1_score(y_train_true, y_train_pred, average='macro'),
            'micro_f1': f1_score(y_train_true, y_train_pred, average='micro'),
            'accuracy': accuracy_score(y_train_true, y_train_pred),
            'recall': recall_score(y_train_true, y_train_pred, average=None)
        }

        val_metrics = evaluate(model, val_loader, device, criterion)

        print(f"\nEpoch {epoch}")
        print(f"Train Loss: {train_loss:.4f} | Val Loss: {val_metrics['loss']:.4f}")
        print(f"Macro-F1: {val_metrics['macro_f1']:.4f} | Micro-F1: {val_metrics['micro_f1']:.4f} | Acc: {val_metrics['accuracy']:.4f} | Recall: {val_metrics['recall']}")

        if val_metrics['macro_f1'] > best_val_macro_f1:
            best_val_macro_f1 = val_metrics['macro_f1']
            best_model_state = model.state_dict()
            print("✅ New best model saved.")

    # Final test eval
    model.load_state_dict(best_model_state)
    test_metrics = evaluate(model, test_loader, device, criterion)

    print("\n🎯 FINAL TEST EVALUATION")
    print(f"Test Loss : {test_metrics['loss']:.4f}")
    print(f"Macro-F1  : {test_metrics['macro_f1']:.4f}")
    print(f"Micro-F1  : {test_metrics['micro_f1']:.4f}")
    print(f"Accuracy  : {test_metrics['accuracy']:.4f}")
    print(f"Recall    : {test_metrics['recall']}")

    torch.save(model.state_dict(), "best_concat_model.pth")
    print("💾 Model saved to best_concat_model.pth")

if __name__ == "__main__":
    train_model()
# Out:
# 📊 Split sizes: {'train': 534, 'val': 107, 'test': 114}
#
# Epoch 1
# Train Loss: 0.9748 | Val Loss: 0.9281
# Macro-F1: 0.2659 | Micro-F1: 0.6636 | Acc: 0.6636 | Recall: [0. 0. 1.]
# ✅ New best model saved.
#
# Epoch 2
# Train Loss: 0.9228 | Val Loss: 0.9156
# Macro-F1: 0.2659 | Micro-F1: 0.6636 | Acc: 0.6636 | Recall: [0. 0. 1.]
#
# Epoch 3
# Train Loss: 0.9190 | Val Loss: 0.9383
# Macro-F1: 0.2590 | Micro-F1: 0.6355 | Acc: 0.6355 | Recall: [0.         0.         0.95774648]
#
# Epoch 4
# Train Loss: 0.8974 | Val Loss: 0.9390
# Macro-F1: 0.3129 | Micro-F1: 0.6542 | Acc: 0.6542 | Recall: [0.         0.0952381  0.95774648]
# ✅ New best model saved.
#
# Epoch 5
# Train Loss: 0.8925 | Val Loss: 0.9239
# Macro-F1: 0.2637 | Micro-F1: 0.6542 | Acc: 0.6542 | Recall: [0.         0.         0.98591549]
#
# Epoch 6
# Train Loss: 0.8892 | Val Loss: 0.9395
# Macro-F1: 0.3272 | Micro-F1: 0.6168 | Acc: 0.6168 | Recall: [0.         0.19047619 0.87323944]
# ✅ New best model saved.
#
# Epoch 7
# Train Loss: 0.8928 | Val Loss: 0.9416
# Macro-F1: 0.3272 | Micro-F1: 0.6168 | Acc: 0.6168 | Recall: [0.         0.19047619 0.87323944]
#
# Epoch 8
# Train Loss: 0.8802 | Val Loss: 0.9374
# Macro-F1: 0.2972 | Micro-F1: 0.6168 | Acc: 0.6168 | Recall: [0.         0.0952381  0.90140845]
#
# Epoch 9
# Train Loss: 0.8864 | Val Loss: 0.9064
# Macro-F1: 0.2637 | Micro-F1: 0.6542 | Acc: 0.6542 | Recall: [0.         0.         0.98591549]
#
# Epoch 10
# Train Loss: 0.8832 | Val Loss: 0.9341
# Macro-F1: 0.2818 | Micro-F1: 0.6262 | Acc: 0.6262 | Recall: [0.         0.04761905 0.92957746]
#
# Epoch 11
# Train Loss: 0.8622 | Val Loss: 0.9088
# Macro-F1: 0.2614 | Micro-F1: 0.6449 | Acc: 0.6449 | Recall: [0.         0.         0.97183099]
#
# Epoch 12
# Train Loss: 0.8664 | Val Loss: 0.9740
# Macro-F1: 0.3255 | Micro-F1: 0.5234 | Acc: 0.5234 | Recall: [0.         0.42857143 0.66197183]
#
# Epoch 13
# Train Loss: 0.8846 | Val Loss: 0.9581
# Macro-F1: 0.3216 | Micro-F1: 0.5607 | Acc: 0.5607 | Recall: [0.         0.28571429 0.76056338]
#
# Epoch 14
# Train Loss: 0.8592 | Val Loss: 0.9184
# Macro-F1: 0.3176 | Micro-F1: 0.6262 | Acc: 0.6262 | Recall: [0.         0.14285714 0.90140845]
#
# Epoch 15
# Train Loss: 0.8535 | Val Loss: 0.9121
# Macro-F1: 0.3087 | Micro-F1: 0.6449 | Acc: 0.6449 | Recall: [0.         0.0952381  0.94366197]
#
# Epoch 16
# Train Loss: 0.8379 | Val Loss: 0.9339
# Macro-F1: 0.3261 | Micro-F1: 0.5701 | Acc: 0.5701 | Recall: [0.         0.28571429 0.77464789]
#
# Epoch 17
# Train Loss: 0.8412 | Val Loss: 0.9567
# Macro-F1: 0.3330 | Micro-F1: 0.5514 | Acc: 0.5514 | Recall: [0.         0.38095238 0.71830986]
# ✅ New best model saved.
#
# Epoch 18
# Train Loss: 0.8328 | Val Loss: 0.9316
# Macro-F1: 0.3208 | Micro-F1: 0.5794 | Acc: 0.5794 | Recall: [0.         0.23809524 0.8028169 ]
#
# Epoch 19
# Train Loss: 0.8358 | Val Loss: 0.9036
# Macro-F1: 0.3088 | Micro-F1: 0.6449 | Acc: 0.6449 | Recall: [0.         0.0952381  0.94366197]
#
# Epoch 20
# Train Loss: 0.8368 | Val Loss: 0.9058
# Macro-F1: 0.3013 | Micro-F1: 0.5888 | Acc: 0.5888 | Recall: [0.         0.14285714 0.84507042]
#
# Epoch 21
# Train Loss: 0.8224 | Val Loss: 0.9166
# Macro-F1: 0.3261 | Micro-F1: 0.5701 | Acc: 0.5701 | Recall: [0.         0.28571429 0.77464789]
#
# Epoch 22
# Train Loss: 0.8166 | Val Loss: 0.9588
# Macro-F1: 0.3423 | Micro-F1: 0.5701 | Acc: 0.5701 | Recall: [0.         0.38095238 0.74647887]
# ✅ New best model saved.
#
# Epoch 23
# Train Loss: 0.8166 | Val Loss: 0.8773
# Macro-F1: 0.2614 | Micro-F1: 0.6449 | Acc: 0.6449 | Recall: [0.         0.         0.97183099]
#
# Epoch 24
# Train Loss: 0.8319 | Val Loss: 0.9435
# Macro-F1: 0.3516 | Micro-F1: 0.5888 | Acc: 0.5888 | Recall: [0.         0.38095238 0.77464789]
# ✅ New best model saved.
#
# Epoch 25
# Train Loss: 0.8018 | Val Loss: 0.8815
# Macro-F1: 0.3014 | Micro-F1: 0.6262 | Acc: 0.6262 | Recall: [0.         0.0952381  0.91549296]
#
# Epoch 26
# Train Loss: 0.7949 | Val Loss: 0.9146
# Macro-F1: 0.3563 | Micro-F1: 0.5981 | Acc: 0.5981 | Recall: [0.         0.38095238 0.78873239]
# ✅ New best model saved.
#
# Epoch 27
# Train Loss: 0.8055 | Val Loss: 0.9060
# Macro-F1: 0.3395 | Micro-F1: 0.5981 | Acc: 0.5981 | Recall: [0.         0.28571429 0.81690141]
#
# Epoch 28
# Train Loss: 0.8054 | Val Loss: 0.9161
# Macro-F1: 0.3307 | Micro-F1: 0.5794 | Acc: 0.5794 | Recall: [0.         0.28571429 0.78873239]
#
# Epoch 29
# Train Loss: 0.7935 | Val Loss: 0.9158
# Macro-F1: 0.3331 | Micro-F1: 0.5514 | Acc: 0.5514 | Recall: [0.         0.38095238 0.71830986]
#
# Epoch 30
# Train Loss: 0.7840 | Val Loss: 0.9260
# Macro-F1: 0.3331 | Micro-F1: 0.5514 | Acc: 0.5514 | Recall: [0.         0.38095238 0.71830986]
#
# Epoch 31
# Train Loss: 0.7838 | Val Loss: 0.8899
# Macro-F1: 0.3144 | Micro-F1: 0.5888 | Acc: 0.5888 | Recall: [0.         0.19047619 0.83098592]
#
# Epoch 32
# Train Loss: 0.7825 | Val Loss: 0.8699
# Macro-F1: 0.2857 | Micro-F1: 0.6355 | Acc: 0.6355 | Recall: [0.         0.04761905 0.94366197]
#
# Epoch 33
# Train Loss: 0.7719 | Val Loss: 0.9190
# Macro-F1: 0.3460 | Micro-F1: 0.5514 | Acc: 0.5514 | Recall: [0.         0.47619048 0.69014085]
#
# Epoch 34
# Train Loss: 0.7642 | Val Loss: 0.8786
# Macro-F1: 0.2877 | Micro-F1: 0.6449 | Acc: 0.6449 | Recall: [0.         0.04761905 0.95774648]
#
# Epoch 35
# Train Loss: 0.7771 | Val Loss: 0.8926
# Macro-F1: 0.3307 | Micro-F1: 0.5794 | Acc: 0.5794 | Recall: [0.         0.28571429 0.78873239]
#
# Epoch 36
# Train Loss: 0.7526 | Val Loss: 0.8701
# Macro-F1: 0.3308 | Micro-F1: 0.6262 | Acc: 0.6262 | Recall: [0.         0.19047619 0.88732394]
#
# Epoch 37
# Train Loss: 0.7479 | Val Loss: 0.8925
# Macro-F1: 0.3220 | Micro-F1: 0.5607 | Acc: 0.5607 | Recall: [0.         0.28571429 0.76056338]
#
# Epoch 38
# Train Loss: 0.7500 | Val Loss: 0.8792
# Macro-F1: 0.3350 | Micro-F1: 0.5888 | Acc: 0.5888 | Recall: [0.         0.28571429 0.8028169 ]
#
# Epoch 39
# Train Loss: 0.7438 | Val Loss: 0.8939
# Macro-F1: 0.3460 | Micro-F1: 0.5514 | Acc: 0.5514 | Recall: [0.         0.47619048 0.69014085]
#
# Epoch 40
# Train Loss: 0.7412 | Val Loss: 0.8892
# Macro-F1: 0.3508 | Micro-F1: 0.5607 | Acc: 0.5607 | Recall: [0.         0.47619048 0.70422535]
#
# Epoch 41
# Train Loss: 0.7416 | Val Loss: 0.9658
# Macro-F1: 0.3549 | Micro-F1: 0.5140 | Acc: 0.5140 | Recall: [0.         0.80952381 0.53521127]
#
# Epoch 42
# Train Loss: 0.7479 | Val Loss: 0.9148
# Macro-F1: 0.3517 | Micro-F1: 0.5421 | Acc: 0.5421 | Recall: [0.         0.57142857 0.64788732]
#
# Epoch 43
# Train Loss: 0.7686 | Val Loss: 0.9898
# Macro-F1: 0.3426 | Micro-F1: 0.4860 | Acc: 0.4860 | Recall: [0.         0.9047619  0.46478873]
#
# Epoch 44
# Train Loss: 0.7579 | Val Loss: 0.9893
# Macro-F1: 0.3348 | Micro-F1: 0.4766 | Acc: 0.4766 | Recall: [0.         0.85714286 0.46478873]
#
# Epoch 45
# Train Loss: 0.7295 | Val Loss: 0.9053
# Macro-F1: 0.3541 | Micro-F1: 0.5794 | Acc: 0.5794 | Recall: [0.         0.42857143 0.74647887]
#
# Epoch 46
# Train Loss: 0.7228 | Val Loss: 0.8579
# Macro-F1: 0.3678 | Micro-F1: 0.5981 | Acc: 0.5981 | Recall: [0.06666667 0.23809524 0.81690141]
# ✅ New best model saved.
#
# Epoch 47
# Train Loss: 0.7079 | Val Loss: 0.8842
# Macro-F1: 0.3381 | Micro-F1: 0.6168 | Acc: 0.6168 | Recall: [0.         0.23809524 0.85915493]
#
# Epoch 48
# Train Loss: 0.7119 | Val Loss: 0.8347
# Macro-F1: 0.4145 | Micro-F1: 0.6542 | Acc: 0.6542 | Recall: [0.13333333 0.19047619 0.90140845]
# ✅ New best model saved.
#
# Epoch 49
# Train Loss: 0.7072 | Val Loss: 0.8717
# Macro-F1: 0.3381 | Micro-F1: 0.6168 | Acc: 0.6168 | Recall: [0.         0.23809524 0.85915493]
#
# Epoch 50
# Train Loss: 0.7139 | Val Loss: 0.8617
# Macro-F1: 0.4011 | Micro-F1: 0.6262 | Acc: 0.6262 | Recall: [0.06666667 0.33333333 0.83098592]
#
# Epoch 51
# Train Loss: 0.7056 | Val Loss: 0.8734
# Macro-F1: 0.3777 | Micro-F1: 0.5514 | Acc: 0.5514 | Recall: [0.06666667 0.42857143 0.69014085]
#
# Epoch 52
# Train Loss: 0.6910 | Val Loss: 0.9416
# Macro-F1: 0.4120 | Micro-F1: 0.5421 | Acc: 0.5421 | Recall: [0.06666667 0.85714286 0.54929577]
#
# Epoch 53
# Train Loss: 0.7107 | Val Loss: 0.9709
# Macro-F1: 0.4009 | Micro-F1: 0.5234 | Acc: 0.5234 | Recall: [0.06666667 0.85714286 0.52112676]
#
# Epoch 54
# Train Loss: 0.7261 | Val Loss: 0.8417
# Macro-F1: 0.3569 | Micro-F1: 0.5981 | Acc: 0.5981 | Recall: [0.06666667 0.19047619 0.83098592]
#
# Epoch 55
# Train Loss: 0.6795 | Val Loss: 0.9082
# Macro-F1: 0.3711 | Micro-F1: 0.5607 | Acc: 0.5607 | Recall: [0.         0.66666667 0.64788732]
#
# Epoch 56
# Train Loss: 0.6974 | Val Loss: 0.8291
# Macro-F1: 0.4145 | Micro-F1: 0.6542 | Acc: 0.6542 | Recall: [0.13333333 0.19047619 0.90140845]
#
# Epoch 57
# Train Loss: 0.6940 | Val Loss: 0.8321
# Macro-F1: 0.3647 | Micro-F1: 0.6449 | Acc: 0.6449 | Recall: [0.06666667 0.14285714 0.91549296]
#
# Epoch 58
# Train Loss: 0.6760 | Val Loss: 0.8453
# Macro-F1: 0.3808 | Micro-F1: 0.6262 | Acc: 0.6262 | Recall: [0.06666667 0.23809524 0.85915493]
#
# Epoch 59
# Train Loss: 0.6955 | Val Loss: 0.9130
# Macro-F1: 0.4218 | Micro-F1: 0.5701 | Acc: 0.5701 | Recall: [0.06666667 0.76190476 0.61971831]
# ✅ New best model saved.
#
# Epoch 60
# Train Loss: 0.6663 | Val Loss: 0.8436
# Macro-F1: 0.4460 | Micro-F1: 0.6355 | Acc: 0.6355 | Recall: [0.13333333 0.38095238 0.81690141]
# ✅ New best model saved.
#
# Epoch 61
# Train Loss: 0.6739 | Val Loss: 0.8867
# Macro-F1: 0.3943 | Micro-F1: 0.5701 | Acc: 0.5701 | Recall: [0.06666667 0.47619048 0.70422535]
#
# Epoch 62
# Train Loss: 0.6747 | Val Loss: 0.8272
# Macro-F1: 0.4372 | Micro-F1: 0.6542 | Acc: 0.6542 | Recall: [0.13333333 0.28571429 0.87323944]
#
# Epoch 63
# Train Loss: 0.6781 | Val Loss: 0.8639
# Macro-F1: 0.3784 | Micro-F1: 0.6449 | Acc: 0.6449 | Recall: [0.06666667 0.19047619 0.90140845]
#
# Epoch 64
# Train Loss: 0.6587 | Val Loss: 0.8597
# Macro-F1: 0.4463 | Micro-F1: 0.5981 | Acc: 0.5981 | Recall: [0.13333333 0.52380952 0.71830986]
# ✅ New best model saved.
#
# Epoch 65
# Train Loss: 0.6618 | Val Loss: 0.8954
# Macro-F1: 0.4088 | Micro-F1: 0.5607 | Acc: 0.5607 | Recall: [0.06666667 0.66666667 0.63380282]
#
# Epoch 66
# Train Loss: 0.6531 | Val Loss: 0.9209
# Macro-F1: 0.3751 | Micro-F1: 0.5607 | Acc: 0.5607 | Recall: [0.         0.71428571 0.63380282]
#
# Epoch 67
# Train Loss: 0.6882 | Val Loss: 0.8502
# Macro-F1: 0.3784 | Micro-F1: 0.6449 | Acc: 0.6449 | Recall: [0.06666667 0.19047619 0.90140845]
#
# Epoch 68
# Train Loss: 0.6726 | Val Loss: 0.8281
# Macro-F1: 0.4279 | Micro-F1: 0.6355 | Acc: 0.6355 | Recall: [0.13333333 0.28571429 0.84507042]
#
# Epoch 69
# Train Loss: 0.6459 | Val Loss: 0.8277
# Macro-F1: 0.4420 | Micro-F1: 0.6636 | Acc: 0.6636 | Recall: [0.13333333 0.28571429 0.88732394]
#
# Epoch 70
# Train Loss: 0.6489 | Val Loss: 0.8280
# Macro-F1: 0.4372 | Micro-F1: 0.6542 | Acc: 0.6542 | Recall: [0.13333333 0.28571429 0.87323944]
#
# Epoch 71
# Train Loss: 0.6637 | Val Loss: 0.9660
# Macro-F1: 0.4310 | Micro-F1: 0.5234 | Acc: 0.5234 | Recall: [0.13333333 0.85714286 0.50704225]
#
# Epoch 72
# Train Loss: 0.6871 | Val Loss: 0.8299
# Macro-F1: 0.4471 | Micro-F1: 0.6542 | Acc: 0.6542 | Recall: [0.13333333 0.33333333 0.85915493]
# ✅ New best model saved.
#
# Epoch 73
# Train Loss: 0.6466 | Val Loss: 0.8353
# Macro-F1: 0.4622 | Micro-F1: 0.6822 | Acc: 0.6822 | Recall: [0.13333333 0.33333333 0.90140845]
# ✅ New best model saved.
#
# Epoch 74
# Train Loss: 0.6241 | Val Loss: 0.8530
# Macro-F1: 0.4514 | Micro-F1: 0.6075 | Acc: 0.6075 | Recall: [0.13333333 0.52380952 0.73239437]
#
# Epoch 75
# Train Loss: 0.6281 | Val Loss: 0.8693
# Macro-F1: 0.4570 | Micro-F1: 0.5981 | Acc: 0.5981 | Recall: [0.13333333 0.61904762 0.69014085]
#
# Epoch 76
# Train Loss: 0.6230 | Val Loss: 0.8542
# Macro-F1: 0.4352 | Micro-F1: 0.5888 | Acc: 0.5888 | Recall: [0.13333333 0.47619048 0.71830986]
#
# Epoch 77
# Train Loss: 0.6192 | Val Loss: 0.8162
# Macro-F1: 0.4571 | Micro-F1: 0.6729 | Acc: 0.6729 | Recall: [0.13333333 0.33333333 0.88732394]
#
# Epoch 78
# Train Loss: 0.6253 | Val Loss: 0.8034
# Macro-F1: 0.4297 | Micro-F1: 0.6636 | Acc: 0.6636 | Recall: [0.13333333 0.23809524 0.90140845]
#
# Epoch 79
# Train Loss: 0.6215 | Val Loss: 0.8653
# Macro-F1: 0.3905 | Micro-F1: 0.6449 | Acc: 0.6449 | Recall: [0.06666667 0.23809524 0.88732394]
#
# Epoch 80
# Train Loss: 0.6356 | Val Loss: 0.8070
# Macro-F1: 0.4123 | Micro-F1: 0.6542 | Acc: 0.6542 | Recall: [0.13333333 0.19047619 0.90140845]
#
# Epoch 81
# Train Loss: 0.6266 | Val Loss: 0.8289
# Macro-F1: 0.4401 | Micro-F1: 0.6449 | Acc: 0.6449 | Recall: [0.13333333 0.33333333 0.84507042]
#
# Epoch 82
# Train Loss: 0.6089 | Val Loss: 0.8380
# Macro-F1: 0.4660 | Micro-F1: 0.6168 | Acc: 0.6168 | Recall: [0.13333333 0.61904762 0.71830986]
# ✅ New best model saved.
#
# Epoch 83
# Train Loss: 0.6061 | Val Loss: 0.8326
# Macro-F1: 0.4455 | Micro-F1: 0.6075 | Acc: 0.6075 | Recall: [0.13333333 0.47619048 0.74647887]
#
# Epoch 84
# Train Loss: 0.6269 | Val Loss: 0.8346
# Macro-F1: 0.4031 | Micro-F1: 0.6542 | Acc: 0.6542 | Recall: [0.13333333 0.14285714 0.91549296]
#
# Epoch 85
# Train Loss: 0.6279 | Val Loss: 0.8373
# Macro-F1: 0.4521 | Micro-F1: 0.6636 | Acc: 0.6636 | Recall: [0.13333333 0.33333333 0.87323944]
#
# Epoch 86
# Train Loss: 0.6161 | Val Loss: 0.8335
# Macro-F1: 0.4832 | Micro-F1: 0.5981 | Acc: 0.5981 | Recall: [0.33333333 0.42857143 0.70422535]
# ✅ New best model saved.
#
# Epoch 87
# Train Loss: 0.6314 | Val Loss: 0.8844
# Macro-F1: 0.4387 | Micro-F1: 0.5514 | Acc: 0.5514 | Recall: [0.13333333 0.71428571 0.5915493 ]
#
# Epoch 88
# Train Loss: 0.6060 | Val Loss: 0.8685
# Macro-F1: 0.4603 | Micro-F1: 0.5888 | Acc: 0.5888 | Recall: [0.13333333 0.71428571 0.64788732]
#
# Epoch 89
# Train Loss: 0.6243 | Val Loss: 0.8209
# Macro-F1: 0.5031 | Micro-F1: 0.6542 | Acc: 0.6542 | Recall: [0.2        0.52380952 0.78873239]
# ✅ New best model saved.
#
# Epoch 90
# Train Loss: 0.6078 | Val Loss: 0.8753
# Macro-F1: 0.4657 | Micro-F1: 0.5981 | Acc: 0.5981 | Recall: [0.13333333 0.71428571 0.66197183]
#
# Epoch 91
# Train Loss: 0.5869 | Val Loss: 0.8119
# Macro-F1: 0.4126 | Micro-F1: 0.6542 | Acc: 0.6542 | Recall: [0.13333333 0.19047619 0.90140845]
#
# Epoch 92
# Train Loss: 0.6011 | Val Loss: 0.8245
# Macro-F1: 0.4983 | Micro-F1: 0.6355 | Acc: 0.6355 | Recall: [0.2        0.57142857 0.74647887]
#
# Epoch 93
# Train Loss: 0.6134 | Val Loss: 0.9697
# Macro-F1: 0.4232 | Micro-F1: 0.5140 | Acc: 0.5140 | Recall: [0.13333333 0.85714286 0.49295775]
#
# Epoch 94
# Train Loss: 0.6219 | Val Loss: 0.8626
# Macro-F1: 0.4694 | Micro-F1: 0.6075 | Acc: 0.6075 | Recall: [0.13333333 0.71428571 0.67605634]
#
# Epoch 95
# Train Loss: 0.5969 | Val Loss: 0.8105
# Macro-F1: 0.4799 | Micro-F1: 0.6822 | Acc: 0.6822 | Recall: [0.2        0.28571429 0.90140845]
#
# Epoch 96
# Train Loss: 0.5899 | Val Loss: 0.8163
# Macro-F1: 0.4681 | Micro-F1: 0.6636 | Acc: 0.6636 | Recall: [0.13333333 0.42857143 0.84507042]
#
# Epoch 97
# Train Loss: 0.5837 | Val Loss: 0.8130
# Macro-F1: 0.4883 | Micro-F1: 0.6822 | Acc: 0.6822 | Recall: [0.2        0.33333333 0.88732394]
#
# Epoch 98
# Train Loss: 0.5877 | Val Loss: 0.8925
# Macro-F1: 0.4657 | Micro-F1: 0.5981 | Acc: 0.5981 | Recall: [0.13333333 0.71428571 0.66197183]
#
# Epoch 99
# Train Loss: 0.5861 | Val Loss: 0.8028
# Macro-F1: 0.4952 | Micro-F1: 0.6636 | Acc: 0.6636 | Recall: [0.2        0.42857143 0.83098592]
#
# Epoch 100
# Train Loss: 0.5775 | Val Loss: 0.8420
# Macro-F1: 0.3665 | Micro-F1: 0.6542 | Acc: 0.6542 | Recall: [0.13333333 0.04761905 0.94366197]
#
# Epoch 101
# Train Loss: 0.5963 | Val Loss: 0.8224
# Macro-F1: 0.5037 | Micro-F1: 0.6355 | Acc: 0.6355 | Recall: [0.2        0.61904762 0.73239437]
# ✅ New best model saved.
#
# Epoch 102
# Train Loss: 0.5861 | Val Loss: 0.8577
# Macro-F1: 0.4769 | Micro-F1: 0.6168 | Acc: 0.6168 | Recall: [0.13333333 0.71428571 0.69014085]
#
# Epoch 103
# Train Loss: 0.5727 | Val Loss: 0.7956
# Macro-F1: 0.4799 | Micro-F1: 0.6822 | Acc: 0.6822 | Recall: [0.2        0.28571429 0.90140845]
#
# Epoch 104
# Train Loss: 0.5787 | Val Loss: 0.8764
# Macro-F1: 0.4452 | Micro-F1: 0.6636 | Acc: 0.6636 | Recall: [0.13333333 0.28571429 0.88732394]
#
# Epoch 105
# Train Loss: 0.5681 | Val Loss: 0.8102
# Macro-F1: 0.4891 | Micro-F1: 0.6542 | Acc: 0.6542 | Recall: [0.2        0.42857143 0.81690141]
#
# Epoch 106
# Train Loss: 0.5659 | Val Loss: 0.8272
# Macro-F1: 0.4604 | Micro-F1: 0.6355 | Acc: 0.6355 | Recall: [0.13333333 0.47619048 0.78873239]
#
# Epoch 107
# Train Loss: 0.5627 | Val Loss: 0.8117
# Macro-F1: 0.4918 | Micro-F1: 0.6449 | Acc: 0.6449 | Recall: [0.2        0.47619048 0.78873239]
#
# Epoch 108
# Train Loss: 0.5596 | Val Loss: 0.8342
# Macro-F1: 0.5199 | Micro-F1: 0.6542 | Acc: 0.6542 | Recall: [0.2        0.66666667 0.74647887]
# ✅ New best model saved.
#
# Epoch 109
# Train Loss: 0.5760 | Val Loss: 0.9173
# Macro-F1: 0.4454 | Micro-F1: 0.5514 | Acc: 0.5514 | Recall: [0.13333333 0.80952381 0.56338028]
#
# Epoch 110
# Train Loss: 0.5820 | Val Loss: 0.8424
# Macro-F1: 0.5019 | Micro-F1: 0.6168 | Acc: 0.6168 | Recall: [0.2        0.71428571 0.67605634]
#
# Epoch 111
# Train Loss: 0.5697 | Val Loss: 0.8439
# Macro-F1: 0.5075 | Micro-F1: 0.6262 | Acc: 0.6262 | Recall: [0.2        0.71428571 0.69014085]
#
# Epoch 112
# Train Loss: 0.5550 | Val Loss: 0.8100
# Macro-F1: 0.5157 | Micro-F1: 0.6636 | Acc: 0.6636 | Recall: [0.2        0.57142857 0.78873239]
#
# Epoch 113
# Train Loss: 0.5509 | Val Loss: 0.8310
# Macro-F1: 0.4656 | Micro-F1: 0.6729 | Acc: 0.6729 | Recall: [0.13333333 0.38095238 0.87323944]
#
# Epoch 114
# Train Loss: 0.5576 | Val Loss: 0.8178
# Macro-F1: 0.4883 | Micro-F1: 0.6822 | Acc: 0.6822 | Recall: [0.2        0.33333333 0.88732394]
#
# Epoch 115
# Train Loss: 0.5879 | Val Loss: 0.9007
# Macro-F1: 0.4691 | Micro-F1: 0.5607 | Acc: 0.5607 | Recall: [0.2        0.76190476 0.57746479]
#
# Epoch 116
# Train Loss: 0.5915 | Val Loss: 0.9077
# Macro-F1: 0.4838 | Micro-F1: 0.5794 | Acc: 0.5794 | Recall: [0.2        0.80952381 0.5915493 ]
#
# Epoch 117
# Train Loss: 0.5689 | Val Loss: 0.8040
# Macro-F1: 0.4830 | Micro-F1: 0.6729 | Acc: 0.6729 | Recall: [0.2        0.33333333 0.87323944]
#
# Epoch 118
# Train Loss: 0.5572 | Val Loss: 0.8359
# Macro-F1: 0.4605 | Micro-F1: 0.6729 | Acc: 0.6729 | Recall: [0.13333333 0.33333333 0.88732394]
#
# Epoch 119
# Train Loss: 0.5475 | Val Loss: 0.8350
# Macro-F1: 0.4921 | Micro-F1: 0.6449 | Acc: 0.6449 | Recall: [0.13333333 0.71428571 0.73239437]
#
# Epoch 120
# Train Loss: 0.5476 | Val Loss: 0.8118
# Macro-F1: 0.5092 | Micro-F1: 0.6542 | Acc: 0.6542 | Recall: [0.2        0.57142857 0.77464789]
#
# Epoch 121
# Train Loss: 0.5426 | Val Loss: 0.8185
# Macro-F1: 0.5446 | Micro-F1: 0.6449 | Acc: 0.6449 | Recall: [0.33333333 0.57142857 0.73239437]
# ✅ New best model saved.
#
# Epoch 122
# Train Loss: 0.5586 | Val Loss: 0.8397
# Macro-F1: 0.4843 | Micro-F1: 0.6542 | Acc: 0.6542 | Recall: [0.13333333 0.57142857 0.78873239]
#
# Epoch 123
# Train Loss: 0.5511 | Val Loss: 0.8206
# Macro-F1: 0.5262 | Micro-F1: 0.6729 | Acc: 0.6729 | Recall: [0.2        0.61904762 0.78873239]
#
# Epoch 124
# Train Loss: 0.5480 | Val Loss: 0.8572
# Macro-F1: 0.4769 | Micro-F1: 0.6168 | Acc: 0.6168 | Recall: [0.13333333 0.71428571 0.69014085]
#
# Epoch 125
# Train Loss: 0.5235 | Val Loss: 0.8038
# Macro-F1: 0.4911 | Micro-F1: 0.6449 | Acc: 0.6449 | Recall: [0.2        0.47619048 0.78873239]
#
# Epoch 126
# Train Loss: 0.5433 | Val Loss: 0.8214
# Macro-F1: 0.5140 | Micro-F1: 0.7103 | Acc: 0.7103 | Recall: [0.2        0.33333333 0.92957746]
#
# Epoch 127
# Train Loss: 0.5333 | Val Loss: 0.8222
# Macro-F1: 0.5092 | Micro-F1: 0.6449 | Acc: 0.6449 | Recall: [0.2        0.61904762 0.74647887]
#
# Epoch 128
# Train Loss: 0.5082 | Val Loss: 0.8420
# Macro-F1: 0.5230 | Micro-F1: 0.6636 | Acc: 0.6636 | Recall: [0.2        0.61904762 0.77464789]
#
# Epoch 129
# Train Loss: 0.5274 | Val Loss: 0.8468
# Macro-F1: 0.4586 | Micro-F1: 0.6542 | Acc: 0.6542 | Recall: [0.13333333 0.38095238 0.84507042]
#
# Epoch 130
# Train Loss: 0.5291 | Val Loss: 0.8450
# Macro-F1: 0.5199 | Micro-F1: 0.6542 | Acc: 0.6542 | Recall: [0.2        0.66666667 0.74647887]
#
# Epoch 131
# Train Loss: 0.5309 | Val Loss: 0.8650
# Macro-F1: 0.4658 | Micro-F1: 0.6822 | Acc: 0.6822 | Recall: [0.13333333 0.33333333 0.90140845]
#
# Epoch 132
# Train Loss: 0.5560 | Val Loss: 0.8352
# Macro-F1: 0.5002 | Micro-F1: 0.6822 | Acc: 0.6822 | Recall: [0.2        0.38095238 0.87323944]
#
# Epoch 133
# Train Loss: 0.5150 | Val Loss: 0.8167
# Macro-F1: 0.4109 | Micro-F1: 0.6542 | Acc: 0.6542 | Recall: [0.26666667 0.04761905 0.91549296]
#
# Epoch 134
# Train Loss: 0.5645 | Val Loss: 0.8388
# Macro-F1: 0.4698 | Micro-F1: 0.6729 | Acc: 0.6729 | Recall: [0.13333333 0.38095238 0.87323944]
#
# Epoch 135
# Train Loss: 0.5316 | Val Loss: 0.9024
# Macro-F1: 0.4667 | Micro-F1: 0.5607 | Acc: 0.5607 | Recall: [0.2        0.76190476 0.57746479]
#
# Epoch 136
# Train Loss: 0.5179 | Val Loss: 0.8170
# Macro-F1: 0.5439 | Micro-F1: 0.6542 | Acc: 0.6542 | Recall: [0.26666667 0.66666667 0.73239437]
#
# Epoch 137
# Train Loss: 0.5258 | Val Loss: 0.8242
# Macro-F1: 0.5156 | Micro-F1: 0.6542 | Acc: 0.6542 | Recall: [0.2        0.61904762 0.76056338]
#
# Epoch 138
# Train Loss: 0.5336 | Val Loss: 0.8546
# Macro-F1: 0.4698 | Micro-F1: 0.6729 | Acc: 0.6729 | Recall: [0.13333333 0.38095238 0.87323944]
#
# Epoch 139
# Train Loss: 0.5134 | Val Loss: 0.8377
# Macro-F1: 0.5092 | Micro-F1: 0.6542 | Acc: 0.6542 | Recall: [0.2        0.57142857 0.77464789]
#
# Epoch 140
# Train Loss: 0.5398 | Val Loss: 0.8983
# Macro-F1: 0.4838 | Micro-F1: 0.5794 | Acc: 0.5794 | Recall: [0.2        0.80952381 0.5915493 ]
#
# Epoch 141
# Train Loss: 0.5354 | Val Loss: 0.8177
# Macro-F1: 0.5439 | Micro-F1: 0.6542 | Acc: 0.6542 | Recall: [0.26666667 0.66666667 0.73239437]
#
# Epoch 142
# Train Loss: 0.5135 | Val Loss: 0.8511
# Macro-F1: 0.4843 | Micro-F1: 0.6542 | Acc: 0.6542 | Recall: [0.13333333 0.57142857 0.78873239]
#
# Epoch 143
# Train Loss: 0.4999 | Val Loss: 0.8283
# Macro-F1: 0.5182 | Micro-F1: 0.6636 | Acc: 0.6636 | Recall: [0.2        0.57142857 0.78873239]
#
# Epoch 144
# Train Loss: 0.5095 | Val Loss: 0.8209
# Macro-F1: 0.5140 | Micro-F1: 0.6822 | Acc: 0.6822 | Recall: [0.2        0.47619048 0.84507042]
#
# Epoch 145
# Train Loss: 0.5132 | Val Loss: 0.8701
# Macro-F1: 0.4960 | Micro-F1: 0.6075 | Acc: 0.6075 | Recall: [0.2        0.71428571 0.66197183]
#
# Epoch 146
# Train Loss: 0.5102 | Val Loss: 1.0531
# Macro-F1: 0.4199 | Micro-F1: 0.4673 | Acc: 0.4673 | Recall: [0.26666667 0.71428571 0.43661972]
#
# Epoch 147
# Train Loss: 0.5922 | Val Loss: 0.8807
# Macro-F1: 0.5018 | Micro-F1: 0.5794 | Acc: 0.5794 | Recall: [0.33333333 0.66666667 0.6056338 ]
#
# Epoch 148
# Train Loss: 0.5100 | Val Loss: 0.8754
# Macro-F1: 0.4990 | Micro-F1: 0.6075 | Acc: 0.6075 | Recall: [0.2        0.71428571 0.66197183]
#
# Epoch 149
# Train Loss: 0.5198 | Val Loss: 0.8995
# Macro-F1: 0.4732 | Micro-F1: 0.5981 | Acc: 0.5981 | Recall: [0.13333333 0.80952381 0.63380282]
#
# Epoch 150
# Train Loss: 0.4944 | Val Loss: 0.8708
# Macro-F1: 0.4689 | Micro-F1: 0.6729 | Acc: 0.6729 | Recall: [0.13333333 0.38095238 0.87323944]
#
# Epoch 151
# Train Loss: 0.4945 | Val Loss: 0.8564
# Macro-F1: 0.4837 | Micro-F1: 0.6449 | Acc: 0.6449 | Recall: [0.13333333 0.61904762 0.76056338]
#
# Epoch 152
# Train Loss: 0.5081 | Val Loss: 0.9165
# Macro-F1: 0.4945 | Micro-F1: 0.6355 | Acc: 0.6355 | Recall: [0.13333333 0.76190476 0.70422535]
#
# Epoch 153
# Train Loss: 0.5243 | Val Loss: 0.7980
# Macro-F1: 0.5369 | Micro-F1: 0.6542 | Acc: 0.6542 | Recall: [0.4        0.42857143 0.77464789]
#
# Epoch 154
# Train Loss: 0.4951 | Val Loss: 0.8116
# Macro-F1: 0.5398 | Micro-F1: 0.6636 | Acc: 0.6636 | Recall: [0.26666667 0.57142857 0.77464789]
#
# Epoch 155
# Train Loss: 0.5097 | Val Loss: 0.9290
# Macro-F1: 0.4803 | Micro-F1: 0.5794 | Acc: 0.5794 | Recall: [0.2        0.76190476 0.6056338 ]
#
# Epoch 156
# Train Loss: 0.4929 | Val Loss: 0.9017
# Macro-F1: 0.4724 | Micro-F1: 0.5701 | Acc: 0.5701 | Recall: [0.2        0.76190476 0.5915493 ]
#
# Epoch 157
# Train Loss: 0.5045 | Val Loss: 0.8295
# Macro-F1: 0.4865 | Micro-F1: 0.6729 | Acc: 0.6729 | Recall: [0.2        0.33333333 0.87323944]
#
# Epoch 158
# Train Loss: 0.4964 | Val Loss: 0.8629
# Macro-F1: 0.4903 | Micro-F1: 0.6822 | Acc: 0.6822 | Recall: [0.13333333 0.47619048 0.85915493]
#
# Epoch 159
# Train Loss: 0.5209 | Val Loss: 0.8151
# Macro-F1: 0.5445 | Micro-F1: 0.6636 | Acc: 0.6636 | Recall: [0.26666667 0.61904762 0.76056338]
#
# Epoch 160
# Train Loss: 0.4841 | Val Loss: 0.8324
# Macro-F1: 0.4929 | Micro-F1: 0.6822 | Acc: 0.6822 | Recall: [0.2        0.33333333 0.88732394]
#
# Epoch 161
# Train Loss: 0.5160 | Val Loss: 0.8542
# Macro-F1: 0.4796 | Micro-F1: 0.6916 | Acc: 0.6916 | Recall: [0.2        0.23809524 0.92957746]
#
# Epoch 162
# Train Loss: 0.4881 | Val Loss: 0.8387
# Macro-F1: 0.5335 | Micro-F1: 0.6822 | Acc: 0.6822 | Recall: [0.2        0.57142857 0.81690141]
#
# Epoch 163
# Train Loss: 0.4934 | Val Loss: 0.8876
# Macro-F1: 0.4990 | Micro-F1: 0.6075 | Acc: 0.6075 | Recall: [0.2        0.71428571 0.66197183]
#
# Epoch 164
# Train Loss: 0.4896 | Val Loss: 0.8037
# Macro-F1: 0.5337 | Micro-F1: 0.6636 | Acc: 0.6636 | Recall: [0.26666667 0.52380952 0.78873239]
#
# Epoch 165
# Train Loss: 0.4717 | Val Loss: 0.8603
# Macro-F1: 0.4761 | Micro-F1: 0.6449 | Acc: 0.6449 | Recall: [0.13333333 0.52380952 0.78873239]
#
# Epoch 166
# Train Loss: 0.4763 | Val Loss: 0.8800
# Macro-F1: 0.4813 | Micro-F1: 0.6449 | Acc: 0.6449 | Recall: [0.13333333 0.57142857 0.77464789]
#
# Epoch 167
# Train Loss: 0.4846 | Val Loss: 0.9125
# Macro-F1: 0.4732 | Micro-F1: 0.5981 | Acc: 0.5981 | Recall: [0.13333333 0.80952381 0.63380282]
#
# Epoch 168
# Train Loss: 0.4890 | Val Loss: 0.8585
# Macro-F1: 0.4947 | Micro-F1: 0.6168 | Acc: 0.6168 | Recall: [0.2        0.66666667 0.69014085]
#
# Epoch 169
# Train Loss: 0.5182 | Val Loss: 0.8096
# Macro-F1: 0.5309 | Micro-F1: 0.7103 | Acc: 0.7103 | Recall: [0.26666667 0.33333333 0.91549296]
#
# Epoch 170
# Train Loss: 0.4852 | Val Loss: 0.8261
# Macro-F1: 0.5215 | Micro-F1: 0.6729 | Acc: 0.6729 | Recall: [0.2        0.57142857 0.8028169 ]
#
# Epoch 171
# Train Loss: 0.4715 | Val Loss: 0.8662
# Macro-F1: 0.4788 | Micro-F1: 0.6449 | Acc: 0.6449 | Recall: [0.13333333 0.57142857 0.77464789]
#
# Epoch 172
# Train Loss: 0.4929 | Val Loss: 0.8399
# Macro-F1: 0.5237 | Micro-F1: 0.6355 | Acc: 0.6355 | Recall: [0.26666667 0.61904762 0.71830986]
#
# Epoch 173
# Train Loss: 0.4948 | Val Loss: 0.9006
# Macro-F1: 0.5035 | Micro-F1: 0.6075 | Acc: 0.6075 | Recall: [0.2        0.80952381 0.63380282]
#
# Epoch 174
# Train Loss: 0.4652 | Val Loss: 0.8884
# Macro-F1: 0.4837 | Micro-F1: 0.6449 | Acc: 0.6449 | Recall: [0.13333333 0.61904762 0.76056338]
#
# Epoch 175
# Train Loss: 0.4874 | Val Loss: 0.8407
# Macro-F1: 0.5037 | Micro-F1: 0.6449 | Acc: 0.6449 | Recall: [0.2        0.57142857 0.76056338]
#
# Epoch 176
# Train Loss: 0.4708 | Val Loss: 0.8370
# Macro-F1: 0.5037 | Micro-F1: 0.6449 | Acc: 0.6449 | Recall: [0.2        0.57142857 0.76056338]
#
# Epoch 177
# Train Loss: 0.4857 | Val Loss: 0.8620
# Macro-F1: 0.4982 | Micro-F1: 0.6262 | Acc: 0.6262 | Recall: [0.2        0.61904762 0.71830986]
#
# Epoch 178
# Train Loss: 0.4825 | Val Loss: 0.8623
# Macro-F1: 0.4916 | Micro-F1: 0.6729 | Acc: 0.6729 | Recall: [0.13333333 0.52380952 0.83098592]
#
# Epoch 179
# Train Loss: 0.4945 | Val Loss: 0.9089
# Macro-F1: 0.4940 | Micro-F1: 0.6355 | Acc: 0.6355 | Recall: [0.13333333 0.76190476 0.70422535]
#
# Epoch 180
# Train Loss: 0.4745 | Val Loss: 0.8717
# Macro-F1: 0.4861 | Micro-F1: 0.6542 | Acc: 0.6542 | Recall: [0.13333333 0.57142857 0.78873239]
#
# Epoch 181
# Train Loss: 0.4823 | Val Loss: 0.8426
# Macro-F1: 0.5204 | Micro-F1: 0.6729 | Acc: 0.6729 | Recall: [0.2        0.57142857 0.8028169 ]
#
# Epoch 182
# Train Loss: 0.4584 | Val Loss: 0.8157
# Macro-F1: 0.5516 | Micro-F1: 0.6542 | Acc: 0.6542 | Recall: [0.4        0.47619048 0.76056338]
# ✅ New best model saved.
#
# Epoch 183
# Train Loss: 0.4642 | Val Loss: 0.7985
# Macro-F1: 0.5397 | Micro-F1: 0.6636 | Acc: 0.6636 | Recall: [0.33333333 0.47619048 0.78873239]
#
# Epoch 184
# Train Loss: 0.4631 | Val Loss: 0.8348
# Macro-F1: 0.5333 | Micro-F1: 0.6542 | Acc: 0.6542 | Recall: [0.26666667 0.57142857 0.76056338]
#
# Epoch 185
# Train Loss: 0.4672 | Val Loss: 0.8218
# Macro-F1: 0.5514 | Micro-F1: 0.7009 | Acc: 0.7009 | Recall: [0.26666667 0.47619048 0.85915493]
#
# Epoch 186
# Train Loss: 0.4683 | Val Loss: 0.9698
# Macro-F1: 0.4923 | Micro-F1: 0.6262 | Acc: 0.6262 | Recall: [0.13333333 0.80952381 0.67605634]
#
# Epoch 187
# Train Loss: 0.4649 | Val Loss: 0.9187
# Macro-F1: 0.4859 | Micro-F1: 0.5888 | Acc: 0.5888 | Recall: [0.2        0.76190476 0.61971831]
#
# Epoch 188
# Train Loss: 0.4577 | Val Loss: 0.8320
# Macro-F1: 0.5333 | Micro-F1: 0.6542 | Acc: 0.6542 | Recall: [0.26666667 0.57142857 0.76056338]
#
# Epoch 189
# Train Loss: 0.4540 | Val Loss: 0.8458
# Macro-F1: 0.5037 | Micro-F1: 0.6449 | Acc: 0.6449 | Recall: [0.2        0.57142857 0.76056338]
#
# Epoch 190
# Train Loss: 0.4444 | Val Loss: 0.8773
# Macro-F1: 0.5081 | Micro-F1: 0.6355 | Acc: 0.6355 | Recall: [0.2        0.66666667 0.71830986]
#
# Epoch 191
# Train Loss: 0.4586 | Val Loss: 0.8857
# Macro-F1: 0.5084 | Micro-F1: 0.6262 | Acc: 0.6262 | Recall: [0.2        0.76190476 0.67605634]
#
# Epoch 192
# Train Loss: 0.4556 | Val Loss: 0.8408
# Macro-F1: 0.5145 | Micro-F1: 0.6449 | Acc: 0.6449 | Recall: [0.26666667 0.52380952 0.76056338]
#
# Epoch 193
# Train Loss: 0.4592 | Val Loss: 0.8307
# Macro-F1: 0.5445 | Micro-F1: 0.6636 | Acc: 0.6636 | Recall: [0.26666667 0.61904762 0.76056338]
#
# Epoch 194
# Train Loss: 0.4586 | Val Loss: 0.8413
# Macro-F1: 0.5468 | Micro-F1: 0.6729 | Acc: 0.6729 | Recall: [0.26666667 0.57142857 0.78873239]
#
# Epoch 195
# Train Loss: 0.4548 | Val Loss: 0.9480
# Macro-F1: 0.4830 | Micro-F1: 0.6168 | Acc: 0.6168 | Recall: [0.13333333 0.76190476 0.67605634]
#
# Epoch 196
# Train Loss: 0.4514 | Val Loss: 0.8703
# Macro-F1: 0.5166 | Micro-F1: 0.6542 | Acc: 0.6542 | Recall: [0.2        0.57142857 0.77464789]
#
# Epoch 197
# Train Loss: 0.4312 | Val Loss: 0.8454
# Macro-F1: 0.5333 | Micro-F1: 0.6542 | Acc: 0.6542 | Recall: [0.26666667 0.57142857 0.76056338]
#
# Epoch 198
# Train Loss: 0.4465 | Val Loss: 0.8496
# Macro-F1: 0.5333 | Micro-F1: 0.6542 | Acc: 0.6542 | Recall: [0.26666667 0.57142857 0.76056338]
#
# Epoch 199
# Train Loss: 0.4373 | Val Loss: 0.8705
# Macro-F1: 0.4982 | Micro-F1: 0.6262 | Acc: 0.6262 | Recall: [0.2        0.61904762 0.71830986]
#
# Epoch 200
# Train Loss: 0.4575 | Val Loss: 0.9105
# Macro-F1: 0.5028 | Micro-F1: 0.6168 | Acc: 0.6168 | Recall: [0.2        0.76190476 0.66197183]
#
# Epoch 201
# Train Loss: 0.4432 | Val Loss: 0.8201
# Macro-F1: 0.5079 | Micro-F1: 0.6449 | Acc: 0.6449 | Recall: [0.26666667 0.47619048 0.77464789]
#
# Epoch 202
# Train Loss: 0.4465 | Val Loss: 0.8778
# Macro-F1: 0.5365 | Micro-F1: 0.6355 | Acc: 0.6355 | Recall: [0.26666667 0.71428571 0.69014085]
#
# Epoch 203
# Train Loss: 0.4525 | Val Loss: 0.9341
# Macro-F1: 0.4724 | Micro-F1: 0.5701 | Acc: 0.5701 | Recall: [0.2        0.76190476 0.5915493 ]
#
# Epoch 204
# Train Loss: 0.4450 | Val Loss: 0.8336
# Macro-F1: 0.5338 | Micro-F1: 0.6449 | Acc: 0.6449 | Recall: [0.4        0.47619048 0.74647887]
#
# Epoch 205
# Train Loss: 0.4574 | Val Loss: 0.8424
# Macro-F1: 0.5456 | Micro-F1: 0.6729 | Acc: 0.6729 | Recall: [0.26666667 0.57142857 0.78873239]
#
# Epoch 206
# Train Loss: 0.4177 | Val Loss: 0.8753
# Macro-F1: 0.5092 | Micro-F1: 0.6542 | Acc: 0.6542 | Recall: [0.2        0.57142857 0.77464789]
#
# Epoch 207
# Train Loss: 0.4207 | Val Loss: 0.9088
# Macro-F1: 0.5055 | Micro-F1: 0.6168 | Acc: 0.6168 | Recall: [0.2        0.76190476 0.66197183]
#
# Epoch 208
# Train Loss: 0.4336 | Val Loss: 0.9864
# Macro-F1: 0.4889 | Micro-F1: 0.5421 | Acc: 0.5421 | Recall: [0.4        0.66666667 0.53521127]
#
# Epoch 209
# Train Loss: 0.4661 | Val Loss: 0.8567
# Macro-F1: 0.5355 | Micro-F1: 0.7103 | Acc: 0.7103 | Recall: [0.26666667 0.33333333 0.91549296]
#
# Epoch 210
# Train Loss: 0.5095 | Val Loss: 0.9689
# Macro-F1: 0.4780 | Micro-F1: 0.7009 | Acc: 0.7009 | Recall: [0.13333333 0.33333333 0.92957746]
#
# Epoch 211
# Train Loss: 0.4438 | Val Loss: 0.9419
# Macro-F1: 0.4790 | Micro-F1: 0.6168 | Acc: 0.6168 | Recall: [0.13333333 0.71428571 0.69014085]
#
# Epoch 212
# Train Loss: 0.4378 | Val Loss: 0.8450
# Macro-F1: 0.5333 | Micro-F1: 0.6542 | Acc: 0.6542 | Recall: [0.26666667 0.57142857 0.76056338]
#
# Epoch 213
# Train Loss: 0.4224 | Val Loss: 0.9307
# Macro-F1: 0.4745 | Micro-F1: 0.6168 | Acc: 0.6168 | Recall: [0.13333333 0.66666667 0.70422535]
#
# Epoch 214
# Train Loss: 0.4298 | Val Loss: 0.8470
# Macro-F1: 0.5408 | Micro-F1: 0.6916 | Acc: 0.6916 | Recall: [0.26666667 0.42857143 0.85915493]
#
# Epoch 215
# Train Loss: 0.4224 | Val Loss: 0.8528
# Macro-F1: 0.5349 | Micro-F1: 0.6355 | Acc: 0.6355 | Recall: [0.33333333 0.57142857 0.71830986]
#
# Epoch 216
# Train Loss: 0.4259 | Val Loss: 0.8899
# Macro-F1: 0.5175 | Micro-F1: 0.6542 | Acc: 0.6542 | Recall: [0.2        0.61904762 0.76056338]
#
# Epoch 217
# Train Loss: 0.4333 | Val Loss: 0.9313
# Macro-F1: 0.4971 | Micro-F1: 0.6075 | Acc: 0.6075 | Recall: [0.2        0.76190476 0.64788732]
#
# Epoch 218
# Train Loss: 0.4503 | Val Loss: 0.8931
# Macro-F1: 0.4943 | Micro-F1: 0.6168 | Acc: 0.6168 | Recall: [0.2        0.66666667 0.69014085]
#
# Epoch 219
# Train Loss: 0.4344 | Val Loss: 0.8313
# Macro-F1: 0.5250 | Micro-F1: 0.6916 | Acc: 0.6916 | Recall: [0.26666667 0.38095238 0.87323944]
#
# Epoch 220
# Train Loss: 0.4115 | Val Loss: 0.8282
# Macro-F1: 0.5389 | Micro-F1: 0.6636 | Acc: 0.6636 | Recall: [0.33333333 0.47619048 0.78873239]
#
# Epoch 221
# Train Loss: 0.4087 | Val Loss: 0.8344
# Macro-F1: 0.5566 | Micro-F1: 0.7196 | Acc: 0.7196 | Recall: [0.26666667 0.47619048 0.88732394]
# ✅ New best model saved.
#
# Epoch 222
# Train Loss: 0.4238 | Val Loss: 0.8874
# Macro-F1: 0.5222 | Micro-F1: 0.6355 | Acc: 0.6355 | Recall: [0.26666667 0.57142857 0.73239437]
#
# Epoch 223
# Train Loss: 0.4146 | Val Loss: 0.8744
# Macro-F1: 0.5166 | Micro-F1: 0.6542 | Acc: 0.6542 | Recall: [0.2        0.57142857 0.77464789]
#
# Epoch 224
# Train Loss: 0.4244 | Val Loss: 0.8726
# Macro-F1: 0.4899 | Micro-F1: 0.6075 | Acc: 0.6075 | Recall: [0.26666667 0.52380952 0.70422535]
#
# Epoch 225
# Train Loss: 0.4113 | Val Loss: 0.8647
# Macro-F1: 0.5501 | Micro-F1: 0.6729 | Acc: 0.6729 | Recall: [0.26666667 0.57142857 0.78873239]
#
# Epoch 226
# Train Loss: 0.4168 | Val Loss: 0.8905
# Macro-F1: 0.5051 | Micro-F1: 0.6355 | Acc: 0.6355 | Recall: [0.2        0.57142857 0.74647887]
#
# Epoch 227
# Train Loss: 0.3962 | Val Loss: 0.9532
# Macro-F1: 0.4701 | Micro-F1: 0.6168 | Acc: 0.6168 | Recall: [0.13333333 0.61904762 0.71830986]
#
# Epoch 228
# Train Loss: 0.3945 | Val Loss: 0.9054
# Macro-F1: 0.4754 | Micro-F1: 0.6355 | Acc: 0.6355 | Recall: [0.13333333 0.57142857 0.76056338]
#
# Epoch 229
# Train Loss: 0.4323 | Val Loss: 0.9235
# Macro-F1: 0.5141 | Micro-F1: 0.6262 | Acc: 0.6262 | Recall: [0.2        0.76190476 0.67605634]
#
# Epoch 230
# Train Loss: 0.4151 | Val Loss: 0.8268
# Macro-F1: 0.5389 | Micro-F1: 0.6636 | Acc: 0.6636 | Recall: [0.33333333 0.47619048 0.78873239]
#
# Epoch 231
# Train Loss: 0.3973 | Val Loss: 0.8868
# Macro-F1: 0.5332 | Micro-F1: 0.6449 | Acc: 0.6449 | Recall: [0.26666667 0.61904762 0.73239437]
#
# Epoch 232
# Train Loss: 0.3964 | Val Loss: 0.8193
# Macro-F1: 0.5713 | Micro-F1: 0.6729 | Acc: 0.6729 | Recall: [0.46666667 0.47619048 0.77464789]
# ✅ New best model saved.
#
# Epoch 233
# Train Loss: 0.4011 | Val Loss: 0.8671
# Macro-F1: 0.5398 | Micro-F1: 0.6636 | Acc: 0.6636 | Recall: [0.26666667 0.57142857 0.77464789]
#
# Epoch 234
# Train Loss: 0.3970 | Val Loss: 0.9362
# Macro-F1: 0.4734 | Micro-F1: 0.6075 | Acc: 0.6075 | Recall: [0.13333333 0.76190476 0.66197183]
#
# Epoch 235
# Train Loss: 0.4024 | Val Loss: 0.9169
# Macro-F1: 0.4754 | Micro-F1: 0.6355 | Acc: 0.6355 | Recall: [0.13333333 0.57142857 0.76056338]
#
# Epoch 236
# Train Loss: 0.4050 | Val Loss: 0.8803
# Macro-F1: 0.5277 | Micro-F1: 0.6449 | Acc: 0.6449 | Recall: [0.26666667 0.57142857 0.74647887]
#
# Epoch 237
# Train Loss: 0.3996 | Val Loss: 0.8475
# Macro-F1: 0.5400 | Micro-F1: 0.6542 | Acc: 0.6542 | Recall: [0.33333333 0.52380952 0.76056338]
#
# Epoch 238
# Train Loss: 0.4045 | Val Loss: 0.8887
# Macro-F1: 0.5166 | Micro-F1: 0.6542 | Acc: 0.6542 | Recall: [0.2        0.57142857 0.77464789]
#
# Epoch 239
# Train Loss: 0.4161 | Val Loss: 0.9186
# Macro-F1: 0.4900 | Micro-F1: 0.6075 | Acc: 0.6075 | Recall: [0.2        0.61904762 0.69014085]
#
# Epoch 240
# Train Loss: 0.4260 | Val Loss: 0.9364
# Macro-F1: 0.5055 | Micro-F1: 0.6168 | Acc: 0.6168 | Recall: [0.2        0.76190476 0.66197183]
#
# Epoch 241
# Train Loss: 0.4266 | Val Loss: 0.9151
# Macro-F1: 0.4749 | Micro-F1: 0.6168 | Acc: 0.6168 | Recall: [0.13333333 0.66666667 0.70422535]
#
# Epoch 242
# Train Loss: 0.3961 | Val Loss: 0.8508
# Macro-F1: 0.5315 | Micro-F1: 0.6636 | Acc: 0.6636 | Recall: [0.33333333 0.42857143 0.8028169 ]
#
# Epoch 243
# Train Loss: 0.4047 | Val Loss: 0.8958
# Macro-F1: 0.5358 | Micro-F1: 0.6262 | Acc: 0.6262 | Recall: [0.33333333 0.66666667 0.67605634]
#
# Epoch 244
# Train Loss: 0.3864 | Val Loss: 0.8859
# Macro-F1: 0.5031 | Micro-F1: 0.6075 | Acc: 0.6075 | Recall: [0.33333333 0.52380952 0.69014085]
#
# Epoch 245
# Train Loss: 0.3856 | Val Loss: 0.8551
# Macro-F1: 0.5442 | Micro-F1: 0.6542 | Acc: 0.6542 | Recall: [0.33333333 0.52380952 0.76056338]
#
# Epoch 246
# Train Loss: 0.4052 | Val Loss: 0.8606
# Macro-F1: 0.5442 | Micro-F1: 0.6542 | Acc: 0.6542 | Recall: [0.33333333 0.52380952 0.76056338]
#
# Epoch 247
# Train Loss: 0.3961 | Val Loss: 0.8456
# Macro-F1: 0.5280 | Micro-F1: 0.6449 | Acc: 0.6449 | Recall: [0.33333333 0.47619048 0.76056338]
#
# Epoch 248
# Train Loss: 0.3948 | Val Loss: 0.9678
# Macro-F1: 0.4812 | Micro-F1: 0.6075 | Acc: 0.6075 | Recall: [0.13333333 0.80952381 0.64788732]
#
# Epoch 249
# Train Loss: 0.3947 | Val Loss: 0.9525
# Macro-F1: 0.5362 | Micro-F1: 0.6075 | Acc: 0.6075 | Recall: [0.33333333 0.76190476 0.61971831]
#
# Epoch 250
# Train Loss: 0.3948 | Val Loss: 0.9473
# Macro-F1: 0.5095 | Micro-F1: 0.6262 | Acc: 0.6262 | Recall: [0.2        0.66666667 0.70422535]
#
# Epoch 251
# Train Loss: 0.3806 | Val Loss: 0.8916
# Macro-F1: 0.5378 | Micro-F1: 0.6542 | Acc: 0.6542 | Recall: [0.26666667 0.57142857 0.76056338]
#
# Epoch 252
# Train Loss: 0.3702 | Val Loss: 0.9131
# Macro-F1: 0.5397 | Micro-F1: 0.6355 | Acc: 0.6355 | Recall: [0.33333333 0.61904762 0.70422535]
#
# Epoch 253
# Train Loss: 0.3919 | Val Loss: 0.8785
# Macro-F1: 0.5158 | Micro-F1: 0.6168 | Acc: 0.6168 | Recall: [0.4        0.47619048 0.70422535]
#
# Epoch 254
# Train Loss: 0.3868 | Val Loss: 0.8904
# Macro-F1: 0.5493 | Micro-F1: 0.6449 | Acc: 0.6449 | Recall: [0.33333333 0.57142857 0.73239437]
#
# Epoch 255
# Train Loss: 0.3772 | Val Loss: 0.9428
# Macro-F1: 0.5264 | Micro-F1: 0.6262 | Acc: 0.6262 | Recall: [0.26666667 0.66666667 0.69014085]
#
# Epoch 256
# Train Loss: 0.3742 | Val Loss: 0.9949
# Macro-F1: 0.4701 | Micro-F1: 0.6262 | Acc: 0.6262 | Recall: [0.13333333 0.57142857 0.74647887]
#
# Epoch 257
# Train Loss: 0.3710 | Val Loss: 0.9027
# Macro-F1: 0.5277 | Micro-F1: 0.6449 | Acc: 0.6449 | Recall: [0.26666667 0.57142857 0.74647887]
#
# Epoch 258
# Train Loss: 0.3735 | Val Loss: 0.8942
# Macro-F1: 0.5461 | Micro-F1: 0.6542 | Acc: 0.6542 | Recall: [0.33333333 0.57142857 0.74647887]
#
# Epoch 259
# Train Loss: 0.3725 | Val Loss: 1.0738
# Macro-F1: 0.4539 | Micro-F1: 0.5607 | Acc: 0.5607 | Recall: [0.13333333 0.85714286 0.56338028]
#
# Epoch 260
# Train Loss: 0.3833 | Val Loss: 0.8649
# Macro-F1: 0.5599 | Micro-F1: 0.6916 | Acc: 0.6916 | Recall: [0.33333333 0.47619048 0.83098592]
#
# Epoch 261
# Train Loss: 0.3868 | Val Loss: 0.8826
# Macro-F1: 0.5549 | Micro-F1: 0.6542 | Acc: 0.6542 | Recall: [0.33333333 0.57142857 0.74647887]
#
# Epoch 262
# Train Loss: 0.3845 | Val Loss: 0.9219
# Macro-F1: 0.5017 | Micro-F1: 0.6355 | Acc: 0.6355 | Recall: [0.2        0.57142857 0.74647887]
#
# Epoch 263
# Train Loss: 0.3911 | Val Loss: 0.8710
# Macro-F1: 0.5662 | Micro-F1: 0.6729 | Acc: 0.6729 | Recall: [0.33333333 0.57142857 0.77464789]
#
# Epoch 264
# Train Loss: 0.3682 | Val Loss: 0.8811
# Macro-F1: 0.5026 | Micro-F1: 0.6168 | Acc: 0.6168 | Recall: [0.33333333 0.47619048 0.71830986]
#
# Epoch 265
# Train Loss: 0.3592 | Val Loss: 0.8882
# Macro-F1: 0.5273 | Micro-F1: 0.6542 | Acc: 0.6542 | Recall: [0.26666667 0.52380952 0.77464789]
#
# Epoch 266
# Train Loss: 0.3684 | Val Loss: 0.9176
# Macro-F1: 0.5433 | Micro-F1: 0.6542 | Acc: 0.6542 | Recall: [0.26666667 0.61904762 0.74647887]
#
# Epoch 267
# Train Loss: 0.3656 | Val Loss: 1.0004
# Macro-F1: 0.4701 | Micro-F1: 0.6262 | Acc: 0.6262 | Recall: [0.13333333 0.57142857 0.74647887]
#
# Epoch 268
# Train Loss: 0.3962 | Val Loss: 0.9217
# Macro-F1: 0.5432 | Micro-F1: 0.6542 | Acc: 0.6542 | Recall: [0.26666667 0.66666667 0.73239437]
#
# Epoch 269
# Train Loss: 0.3500 | Val Loss: 0.9074
# Macro-F1: 0.5378 | Micro-F1: 0.6542 | Acc: 0.6542 | Recall: [0.26666667 0.57142857 0.76056338]
#
# Epoch 270
# Train Loss: 0.3650 | Val Loss: 0.8564
# Macro-F1: 0.5157 | Micro-F1: 0.6355 | Acc: 0.6355 | Recall: [0.33333333 0.47619048 0.74647887]
#
# Epoch 271
# Train Loss: 0.3554 | Val Loss: 0.8741
# Macro-F1: 0.5442 | Micro-F1: 0.6542 | Acc: 0.6542 | Recall: [0.33333333 0.52380952 0.76056338]
#
# Epoch 272
# Train Loss: 0.3721 | Val Loss: 0.9684
# Macro-F1: 0.5101 | Micro-F1: 0.5888 | Acc: 0.5888 | Recall: [0.33333333 0.66666667 0.61971831]
#
# Epoch 273
# Train Loss: 0.3645 | Val Loss: 0.8777
# Macro-F1: 0.5442 | Micro-F1: 0.6542 | Acc: 0.6542 | Recall: [0.33333333 0.52380952 0.76056338]
#
# Epoch 274
# Train Loss: 0.3652 | Val Loss: 0.8561
# Macro-F1: 0.5406 | Micro-F1: 0.6916 | Acc: 0.6916 | Recall: [0.33333333 0.38095238 0.85915493]
#
# Epoch 275
# Train Loss: 0.4066 | Val Loss: 0.8823
# Macro-F1: 0.5343 | Micro-F1: 0.6916 | Acc: 0.6916 | Recall: [0.33333333 0.33333333 0.87323944]
#
# Epoch 276
# Train Loss: 0.3569 | Val Loss: 1.0275
# Macro-F1: 0.4724 | Micro-F1: 0.5701 | Acc: 0.5701 | Recall: [0.2        0.76190476 0.5915493 ]
#
# Epoch 277
# Train Loss: 0.3674 | Val Loss: 0.9005
# Macro-F1: 0.5549 | Micro-F1: 0.6542 | Acc: 0.6542 | Recall: [0.33333333 0.57142857 0.74647887]
#
# Epoch 278
# Train Loss: 0.3405 | Val Loss: 0.9542
# Macro-F1: 0.5480 | Micro-F1: 0.6729 | Acc: 0.6729 | Recall: [0.26666667 0.52380952 0.8028169 ]
#
# Epoch 279
# Train Loss: 0.3478 | Val Loss: 0.8867
# Macro-F1: 0.5001 | Micro-F1: 0.6168 | Acc: 0.6168 | Recall: [0.33333333 0.47619048 0.71830986]
#
# Epoch 280
# Train Loss: 0.3555 | Val Loss: 0.8736
# Macro-F1: 0.5055 | Micro-F1: 0.6262 | Acc: 0.6262 | Recall: [0.33333333 0.47619048 0.73239437]
#
# Epoch 281
# Train Loss: 0.3500 | Val Loss: 0.9231
# Macro-F1: 0.5596 | Micro-F1: 0.6542 | Acc: 0.6542 | Recall: [0.33333333 0.61904762 0.73239437]
#
# Epoch 282
# Train Loss: 0.3556 | Val Loss: 0.9328
# Macro-F1: 0.5390 | Micro-F1: 0.6262 | Acc: 0.6262 | Recall: [0.33333333 0.66666667 0.67605634]
#
# Epoch 283
# Train Loss: 0.3336 | Val Loss: 0.9235
# Macro-F1: 0.5330 | Micro-F1: 0.6449 | Acc: 0.6449 | Recall: [0.26666667 0.57142857 0.74647887]
#
# Epoch 284
# Train Loss: 0.3350 | Val Loss: 0.9530
# Macro-F1: 0.5071 | Micro-F1: 0.6449 | Acc: 0.6449 | Recall: [0.2        0.57142857 0.76056338]
#
# Epoch 285
# Train Loss: 0.3523 | Val Loss: 1.0577
# Macro-F1: 0.4694 | Micro-F1: 0.6355 | Acc: 0.6355 | Recall: [0.13333333 0.52380952 0.77464789]
#
# Epoch 286
# Train Loss: 0.3720 | Val Loss: 0.9172
# Macro-F1: 0.5497 | Micro-F1: 0.6822 | Acc: 0.6822 | Recall: [0.26666667 0.52380952 0.81690141]
#
# Epoch 287
# Train Loss: 0.3397 | Val Loss: 0.9919
# Macro-F1: 0.5362 | Micro-F1: 0.6075 | Acc: 0.6075 | Recall: [0.33333333 0.76190476 0.61971831]
#
# Epoch 288
# Train Loss: 0.3407 | Val Loss: 0.9204
# Macro-F1: 0.5550 | Micro-F1: 0.6542 | Acc: 0.6542 | Recall: [0.33333333 0.61904762 0.73239437]
#
# Epoch 289
# Train Loss: 0.3334 | Val Loss: 0.9347
# Macro-F1: 0.5270 | Micro-F1: 0.6168 | Acc: 0.6168 | Recall: [0.33333333 0.66666667 0.66197183]
#
# Epoch 290
# Train Loss: 0.3519 | Val Loss: 0.8813
# Macro-F1: 0.5226 | Micro-F1: 0.6355 | Acc: 0.6355 | Recall: [0.33333333 0.47619048 0.74647887]
#
# Epoch 291
# Train Loss: 0.3541 | Val Loss: 0.8643
# Macro-F1: 0.5369 | Micro-F1: 0.6729 | Acc: 0.6729 | Recall: [0.33333333 0.42857143 0.81690141]
#
# Epoch 292
# Train Loss: 0.3560 | Val Loss: 0.8763
# Macro-F1: 0.5369 | Micro-F1: 0.6729 | Acc: 0.6729 | Recall: [0.33333333 0.42857143 0.81690141]
#
# Epoch 293
# Train Loss: 0.3232 | Val Loss: 0.8932
# Macro-F1: 0.5376 | Micro-F1: 0.6542 | Acc: 0.6542 | Recall: [0.33333333 0.47619048 0.77464789]
#
# Epoch 294
# Train Loss: 0.3560 | Val Loss: 0.8826
# Macro-F1: 0.5055 | Micro-F1: 0.6262 | Acc: 0.6262 | Recall: [0.33333333 0.47619048 0.73239437]
#
# Epoch 295
# Train Loss: 0.3462 | Val Loss: 0.9233
# Macro-F1: 0.5257 | Micro-F1: 0.6262 | Acc: 0.6262 | Recall: [0.33333333 0.57142857 0.70422535]
#
# Epoch 296
# Train Loss: 0.3313 | Val Loss: 0.9692
# Macro-F1: 0.5345 | Micro-F1: 0.6168 | Acc: 0.6168 | Recall: [0.33333333 0.71428571 0.64788732]
#
# Epoch 297
# Train Loss: 0.3234 | Val Loss: 0.9255
# Macro-F1: 0.5330 | Micro-F1: 0.6449 | Acc: 0.6449 | Recall: [0.26666667 0.57142857 0.74647887]
#
# Epoch 298
# Train Loss: 0.3205 | Val Loss: 0.9230
# Macro-F1: 0.5289 | Micro-F1: 0.6262 | Acc: 0.6262 | Recall: [0.33333333 0.57142857 0.70422535]
#
# Epoch 299
# Train Loss: 0.3474 | Val Loss: 0.8764
# Macro-F1: 0.5486 | Micro-F1: 0.6729 | Acc: 0.6729 | Recall: [0.33333333 0.47619048 0.8028169 ]
#
# Epoch 300
# Train Loss: 0.3425 | Val Loss: 0.9154
# Macro-F1: 0.4917 | Micro-F1: 0.5981 | Acc: 0.5981 | Recall: [0.33333333 0.47619048 0.69014085]
#
# 🎯 FINAL TEST EVALUATION
# Test Loss : 0.8776
# Macro-F1  : 0.5860
# Micro-F1  : 0.6404
# Accuracy  : 0.6404
# Recall    : [0.5        0.44827586 0.75362319]
# 💾 Model saved to best_concat_model.pth

# %%
import pickle
import pandas as pd

# --- Paths ---
pickle_path = 'fused_tensor_data.pkl'
csv_path = "/data/home/huixian/Documents/Homeworks/535_project/MOSEI-Seg/Labels/new_sentiment_split_2.csv"

# --- Load pickle ---
with open(pickle_path, 'rb') as f:
    data = pickle.load(f)
pickle_base_videos = set(item[-1] for item in data)
print(f"📦 Pickle: {len(pickle_base_videos)} unique base_video values")

# --- Load CSV ---
df = pd.read_csv(csv_path)
csv_base_videos = set(df['base_video'].unique())
print(f"📄 CSV: {len(csv_base_videos)} unique base_video values")

# --- Compare ---
intersection = pickle_base_videos & csv_base_videos
only_in_pickle = pickle_base_videos - csv_base_videos
only_in_csv = csv_base_videos - pickle_base_videos

print(f"✅ Matched base_video entries: {len(intersection)}")
print(f"❌ In pickle but not in CSV: {len(only_in_pickle)}")
print(f"❌ In CSV but not in pickle: {len(only_in_csv)}")

# --- Show sample mismatches ---
print("\n🔍 Sample mismatches (in pickle only):")
for i, item in enumerate(sorted(only_in_pickle)):
    print(f"  [Pickle] {item}")
    if i >= 9: break

print("\n🔍 Sample mismatches (in CSV only):")
for i, item in enumerate(sorted(only_in_csv)):
    print(f"  [CSV] {item}")
    if i >= 9: break
# Out:
# 📦 Pickle: 3 unique base_video values
# 📄 CSV: 755 unique base_video values
# ✅ Matched base_video entries: 0
# ❌ In pickle but not in CSV: 3
# ❌ In CSV but not in pickle: 755
#
# 🔍 Sample mismatches (in pickle only):
#   [Pickle] test
#   [Pickle] train
#   [Pickle] val
#
# 🔍 Sample mismatches (in CSV only):
#   [CSV] -3g5yACwYnA
#   [CSV] -3nNcZdcdvU
#   [CSV] -HeZS2-Prhc
#   [CSV] -I_e4mIh0yE
#   [CSV] -MeTTeMJBNc
#   [CSV] -THoVjtIkeU
#   [CSV] -UUCSKoHeMA
#   [CSV] -ZgjBOA1Yhw
#   [CSV] -aqamKhZ1Ec
#   [CSV] -dxfTGcXJoc
